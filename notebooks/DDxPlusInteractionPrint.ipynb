# %%
import ast
import json
import random
import os
import copy
import sys
from collections import namedtuple, defaultdict, OrderedDict

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import hashlib

# %%
class AttrDict(dict):
    def __init__(self, *args, **kwargs):
        dict.__init__(self, *args, **kwargs)
        self.__dict__ = self
    def copy(self):
        return type(self)(**{k: v.copy() if isinstance(v, AttrDict) else v
            for k, v in self.items()})

# %%
def clean(data):
    result = data.replace("\r\n", " ")
    result = result.replace("\r", " ")
    result = result.replace("\n", " ")
    result = result.replace(",", " ")
    return result

def load_json_data(data_filepath, key_name):
    with open(data_filepath) as fp:
        data = json.load(fp)
    index_2_key = sorted(list(data.keys()))
    for k in index_2_key:
        data[k][key_name] = clean(data[k][key_name])
    name_2_index = {data[index_2_key[i]][key_name]: i for i in range(len(index_2_key))}
    data_names = [data[k][key_name] for k in index_2_key]    
    return index_2_key, name_2_index, data

# %%
fr_evidence_2_statements = {
    "fievre": "I have fever",
    "douleurxx_endroitducorps": "The pain locations are",
    "douleurxx": "I feel pain",
    "douleurxx_irrad": "The pain radiates to these locations",
    "douleurxx_carac": "The pain is",
    "douleurxx_soudain": "On a scale of 0-10, the pace at which the pain appear is",
    "douleurxx_intens": "On a scale of 0-10, the pain intensity is",
    "douleurxx_precis": "On a scale of 0-10, the pain's location precision is",
    "pdc": "I lost consciousness",
    "lesions_peau_endroitducorps": "The regions affected by the rash are",
    "lesions_peau": "I have rashes",
    "lesions_peau_couleur": "The color of the rash is",
    "lesions_peau_intens": "On a scale of 0-10, the pain intensity caused by the rash is",
    "lesions_peau_elevee": "On a scale of 0-10, the rash swelling is",
    "lesions_peau_prurit": "On a scale of 0-10, the severity of the rash itching is",
    "lesions_peau_plusqu1cm": "The rash lesions are larger than 1cm",
    "lesions_peau_desquame": "The rash lesions peel off",
    "pale": "My skin is much paler than usual",
    "palpit": "I feel palpitations",
    "vo_sg": "I have recently thrown up blood or something resembling coffee beans",
    "melena": "I have recently had stools that were black (like coal)",
    "diarrhee": "I have diarrhea or an increase in stool frequency",
    "etouff": "I feel like choking or suffocating",
    "fatig_mod": "I constantly feel fatigued ",
    "irritable": "I feel more irritable and  my mood has been very unstable recently",
    "faible": "I feel like I am about to faint",
    "nausee": "I have nausea",
    "friss": "I have shivers",
    "ww_respi": "I have pain which increases when I breathe in deeply",
    "perte_appet": "I have a loss of appetite",
    "rectorragie": "I noticed light red blood or blood clots in my stool",
    "perte_poids": "I had an involuntary weight loss over the last 3 months",
    "pyrosis": "I have a burning sensation that starts in my stomach then goes up into my throat, and can be associated with a bitter taste in my mouth?",
    "bw_bending": "I have pain that improves when I lean forward",
    "ww_effort": "I have symptoms that increase with physical exertion but alleviate with rest",
    "footnumb": "I have numbness, loss of sensation or tingling in the feet",
    "dyspn": "I am experiencing shortness of breath or difficulty breathing in a significant way",
    "pertes_vag": "I have had vaginal discharge",
    "ballon_abdo": "I feel my abdomen is bloated or distended",
    "larmes": "I feel that my eyes produce excessive tears",
    "rhino_clair": "I have nasal congestion",
    "fatig_ext": "I feel so tired that I am unable to do my usual activities",
    "convulsion": "I had an absence episode and lost consciousness",
    "paralysie_visage": "I have had weakness or paralysis on one side of the face",
    "msk_dlr": "I have diffuse muscle pain",
    "ww_bouger": "I have pain that is increased with movement",
    "toux": "I am coughing",
    "ww_dd": "My symptoms worse when lying down and alleviated while sitting up",
    "ww_bouffe": "I have symptoms that get worse after eatin",
    "dysp_effort": "I feel out of breath with minimal physical effort",
    "gain_poids": "I have gained weight recently",
    "anxiete_s": "I feel anxious",
    "diaph": "I have had significantly increased sweating",
    "gorge_dlr": "I have a sore throat",
    "adp_dlr": "I have swollen and painful lymph nodes",
    "etourdissement": "I feel slightly dizzy or lightheaded",
    "hta": "I have high blood pressure",
    "dysphagie": "I have difficulty swallowing",
    "erytheme_occ": "I have noticed a widespread redness in one or both eyes",
    "trismus": "I suddenly have difficulty to open my mouth or have jaw pain when opening it",
    "dysarthrie": "I have difficulty articulating words",
    "laryngospasme": "I have felt like I was suffocating for a very short time with an inability to breathe or speak",
    "sialorhee": "I have noticed that I produce more saliva than usual",
    "confusion": "I have felt confused or disorientated lately",
    "volume_parole": "I have noticed that the tone of my voice has become deeper, softer or hoarse",
    "ulc\u00e8res_bouche": "I have painful mouth ulcers",
    "diplopie": "I have the perception of seeing two images of a single object seen overlapping or adjacent to each other",
    "toux_sev": "I have intense coughing fits",
    "claud_m\u00e2choire": "I have pain in my jaw",
    "ptose": "I have a hard time opening/raising one or both eyelids",
    "faiblesse_msmi": "I feel weakness in both arms and both legs",
    "fatigabilit\u00e9_msk": "My symptoms of muscle weakness increase with fatigue and stress",
    "vo_violent": "I have vomited several times",
    "posttus_emesis": "I vomitted after coughing",
    "insp_siffla": "My breathing is noisy after coughing spells",
    "rds_sg": "I have noticed unusual bleeding or bruising",
    "oedeme_endroitducorps": "The swelling locations are",
    "oedeme": "I have swelling in one or more areas of your body",
    "crach_sg": "I have been coughing up blood",
    "stridor": "I have noticed a high pitched sound when breathing in",
    "faiblesse faciale": "I have noticed weakness in my facial muscles and eyes",
    "paresthesies_bilat": "I have recently had numbness, loss of sensation or tingling, in both arms and legs and around my mouth",
    "rds_paralys_gen": "I have had paralysis in my limbs or in my face",
    "contact_allergie": "I have eaten something that I have an allergy to",
    "wheez": "I have noticed a wheezing sound when I exhale",
    "obstipation": "I have been able to pass stools or gas since my symptoms increased",
    "boire_ped": "I have a decrease in appetite",
    "ww_valsalva": "My symptoms increase with coughing or an effort like lifting a weight",
    "toux_Aboy": "I have a whooping cough",
    "ww_nuit": "My symptoms are more prominent at night",
    "surg1": "I have had surgery within the last month",
    "prurit_occ": "I have severe itching in one or both eyes",
    "expecto": "My cough produces colored or more abundant sputum than usual",
    "angor_accelere": "My symptoms have worsened over the last 2 weeks and progressively less effort is required to cause the symptoms",
    "angor_repos": "I have chest pain even at rest",
    "prurit_nasal": "My nose or the back of my throat is itchy",
    "rds_paresthesie_gen": "I have recently had numbness, loss of sensation or tingling on my body",
    "rds_deg": "I have noticed a generalized and vague discomfort with diffuse  muscle aches",
    "rds_anorexie": "I have been unintentionally losing weight",
    "m\u00e9norr": "I have very long menstruation periods",
    "flushing": "My cheeks suddenly turned red",
    "spasme_trapeze": "I feel that muscle spasms or soreness in my neck are keeping me from turning my head to one side",
    "selles_pale": "I have pale stools and dark urine",
    "pls_irreg": "I feel my heart is beating very irregularly in a disorganized pattern",
    "spasmes_msk": "I have annoying muscle spasms in my face/neck",
    "protu_langue": "I have trouble keeping my tongue in my mouth",
    "regard_d\u00e9vi\u00e9": "I am unable to control the direction of my eyes",
    "dyspn_noct": "I have bouts of choking or shortness of breath that wake me up at night",
    "f10.129": "I drink alcohol excessively",
    "naco": "I am taking a new oral anticoagulants",
    "psy_depers": "I feel like I am detached from my own body or my surroundings",
    "impression_mort": "I feel like I am dying",
    "rhino_pur": "I have greenish/yellowish nasal discharge",
    "hyponos": "I have lost my sense of smell",
    "apnee": "I temporarily stop breathing while I am asleep",
    "i25.1": "I have had a heart attack",
    "i73.9": "I have a problem with poor blood circulation",
    "i10": "I take medications to treat high blood pressure",
    "f17.210": "I smoke cigarettes",
    "e78.5": "I am taking medications to treat high cholesterol",
    "contact": "I have been in contact with a person with similar symptoms in the past 2 weeks",
    "horm1": "I currently take hormones",
    "e10_e11": "I have diabetes",
    "preg1": "I am pregnant",
    "itss_risque": "I have had unprotected sex with more than one partner in the last 6 months",
    "e66": "I am significantly overweight compared to people of the same height as me",
    "ains": "I have recently taken anti-inflammatory drugs",
    "pneumothorax": "Some family members have had a pneumothorax",
    "Z99.2": "I am currently undergo dialysis",
    "atcd_cluster": "Some family members have been diagnosed with cluster headaches",
    "rx_vasodil": "I take medications that dilates your blood vessels",
    "s09.90": "I have had a head trauma",
    "histfammigraine": "Some family members are known to have migraines",
    "i60-i69": "I have had a stroke",
    "z84.89": "I am more likely to develop common allergies than the general population",
    "drogues_stimul": "I regularly take stimulant drugs",
    "dayc": "I work in a daycare",
    "g20": "I have the Parkinson's disease",
    "cancer_m\u00e9ta": "I have a metastatic cancer",
    "osteoporose": "I am being treated for osteoporosis",
    "j45": "I have had to use a bronchodilator in the past",
    "hernie_hiatale": "I have a hiatal hernia",
    "j06.9": "I have had a cold in the last 2 weeks",
    "crowd": "I live with 4 or more people",
    "HIV": "I am infected with the human immunodeficiency virus (HIV)",
    "z92.25": "I am immunosuppressed",
    "drogues_IV": "I am currently using intravenous drugs",
    "crohn_cu": "I suffer from Crohn's disease or ulcerative colitis",
    "atcd_its": "I have had a sexually transmitted infection",
    "move": "I exercise regularly, 4 times per week or more",
    "smokingpast": "I am a former smoker",
    "v85.0": "I am underweight",
    "k74": "I have liver cirrhosis",
    "sex_vih": "I have had sexual intercourse with an HIV-positive partner in the past 12 months",
    "Mauv_aliment": "I have a poor diet",
    "atcd_anem": "I have had a diagnosis of anemia",
    "atcd_fam_anem": "Some family members have been diagnosed with anemia",
    "irc": "I have chronic kidney failure",
    "perinatality": "I was born prematurely",
    "atcdfam_mg": "Some family members have been diagnosed with myasthenia gravis",
    "ap_par": "I have Rheumatoid Arthritis",
    "f32": "I have been diagnosed with depression",
    "cont_coq": "I have been in contact with someone who has had whoooping cough",
    "B34.9": "I have recently had a viral infection",
    "H6690": "I have recently been treated with an oral antibiotic for an ear infection",
    "c00-d48": "I have an active cancer",
    "vaccination": "my vaccinations are up to date",
    "malf_cardiaque": "I have a known heart defect",
    "ap_hypert4": "I have been diagnosed with hyperthyroidism",
    "bode": "I have severe Chronic Obstructive Pulmonary Disease",
    "ap_valve": "I have a known issue with one of my heart valves",
    "drink_energie": "I regularly consume energy drinks",
    "cafe": "I regularly drink coffee or tea",
    "wakeup": "I have recently taken decongestants or substances that may have stimulant effects",
    "allergie_sev": "I have a known severe food allergy",
    "cortico": "I take corticosteroids",
    "J05.0": "Some family members have had croup",
    "f41.9": "I suffer from chronic anxiety",
    "i80": "I have had deep vein thrombosis",
    "immob1": "I have been unable to move or get up for more than 3 consecutive days within the last 4 weeks",
    "ap_asian": "I am of Asian descent",
    "ap_fk": "I have cystic fibrosis",
    "j17_j18": "I have had pneumonia",
    "j44_j42": "I have a chronic obstructive pulmonary disease",
    "urban1": "I live in in a big city",
    "fam_atopie": "Some family members suffer from allergies, hay fever or eczema",
    "fam_j45": "Some family members have asthma",
    "menarche_hat": "I have my first menstrual period before the age of 12",
    "allait_prol": "I have breastfed one of my children for more than 9 months",
    "sahs": "I have been diagnosed with obstructive sleep apnea",
    "i50": "I have heart failure",
    "patho_endo": "I was diagnosed with a hormonal dysfunction",
    "scombroide": "I ate tuna and Swiss cheese before the reaction occurred",
    "K86.1": "I have chronic pancreatitis",
    "k21": "I have been diagnosed with gastroesophageal reflux",
    "ap_pneumothorax": "I have had a spontaneous pneumothorax",
    "z77.22": "I am exposed to secondhand cigarette smoke on a daily basis",
    "antipsy_r\u00e9cent": "I have taken some antipsychotic medications within the last 7 days",
    "nau_psy_recent": "I have been treated in hospital recently for nausea, agitation, intoxication or aggressive behavior and received medication via an intravenous or intramuscular route",
    "lymphoed\u00e8me": "I have had surgery to remove lymph nodes",
    "norvasc": "I take a calcium channel blockers as medications",
    "synd_nephro": "I have a known kidney problem resulting in an inability to retain proteins",
    "I30": "I have had a pericarditis",
    "atcdpsyfam": "Some members of my immediate family have a psychiatric illness",
    "z82.49": "I have close family members who had a cardiovascular disease problem before the age of 50",
    "ebolacase": "I have been in contact with anyone infected with the Ebola virus in the last month",
    "m79.7": "I suffer from fibromyalgia",
    "hosptisasm": "I have been hospitalized for an asthma attack in the past year",
    "criseasthm": "I have had more than one asthma attack in the past year",
    "j32": "I have been diagnosed with chronic sinusitis",
    "eampoc1": "I have had one or several flare ups of chronic obstructive pulmonary disease",
    "tagri": "I work in agriculture",
    "tmine": "I work in the mining sector",
    "tconst": "I work in construction",
    "j34.2": "I have a deviated nasal septum",
    "j33": "I have polyps in my nose",
    "momasthma": "My mother suffers from asthma",
    "suburb": "I live in the suburbs",
    "rural": "I live in a rural area",
    "z80.1": "Some family members have had lung cancer",
    "z80.0": "Some family members have been diagnosed with pancreatic cancer",
    "J81": "I have had fluid in your lungs",
    "trav1": "I have recently travelled to",
}

# %%
en_evidence_2_statements = {
     'E_91': 'I have fever',
     'E_55': 'The pain locations are',
     'E_53': 'I feel pain',
     'E_57': 'The pain radiates to these locations',
     'E_54': 'The pain is',
     'E_59': 'On a scale of 0-10, the pace at which the pain appear is',
     'E_56': 'On a scale of 0-10, the pain intensity is',
     'E_58': "On a scale of 0-10, the pain's location precision is",
     'E_159': 'I lost consciousness',
     'E_133': 'The regions affected by the rash are',
     'E_129': 'I have rashes',
     'E_130': 'The color of the rash is',
     'E_134': 'On a scale of 0-10, the pain intensity caused by the rash is',
     'E_132': 'On a scale of 0-10, the rash swelling is',
     'E_136': 'On a scale of 0-10, the severity of the rash itching is',
     'E_135': 'The rash lesions are larger than 1cm',
     'E_131': 'The rash lesions peel off',
     'E_154': 'My skin is much paler than usual',
     'E_155': 'I feel palpitations',
     'E_210': 'I have recently thrown up blood or something resembling coffee beans',
     'E_140': 'I have recently had stools that were black (like coal)',
     'E_51': 'I have diarrhea or an increase in stool frequency',
     'E_75': 'I feel like choking or suffocating',
     'E_89': 'I constantly feel fatigued ',
     'E_114': 'I feel more irritable and  my mood has been very unstable recently',
     'E_82': 'I feel like I am about to faint',
     'E_148': 'I have nausea',
     'E_94': 'I have shivers',
     'E_220': 'I have pain which increases when I breathe in deeply',
     'E_161': 'I have a loss of appetite',
     'E_179': 'I noticed light red blood or blood clots in my stool',
     'E_162': 'I had an involuntary weight loss over the last 3 months',
     'E_173': 'I have a burning sensation that starts in my stomach then goes up into my throat, and can be associated with a bitter taste in my mouth?',
     'E_33': 'I have pain that improves when I lean forward',
     'E_218': 'I have symptoms that increase with physical exertion but alleviate with rest',
     'E_93': 'I have numbness, loss of sensation or tingling in the feet',
     'E_66': 'I am experiencing shortness of breath or difficulty breathing in a significant way',
     'E_163': 'I have had vaginal discharge',
     'E_30': 'I feel my abdomen is bloated or distended',
     'E_127': 'I feel that my eyes produce excessive tears',
     'E_181': 'I have nasal congestion',
     'E_88': 'I feel so tired that I am unable to do my usual activities',
     'E_43': 'I had an absence episode and lost consciousness',
     'E_156': 'I have had weakness or paralysis on one side of the face',
     'E_144': 'I have diffuse muscle pain',
     'E_216': 'I have pain that is increased with movement',
     'E_201': 'I am coughing',
     'E_217': 'My symptoms worse when lying down and alleviated while sitting up',
     'E_215': 'I have symptoms that get worse after eatin',
     'E_64': 'I feel out of breath with minimal physical effort',
     'E_96': 'I have gained weight recently',
     'E_16': 'I feel anxious',
     'E_50': 'I have had significantly increased sweating',
     'E_97': 'I have a sore throat',
     'E_9': 'I have swollen and painful lymph nodes',
     'E_76': 'I feel slightly dizzy or lightheaded',
     'E_102': 'I have high blood pressure',
     'E_65': 'I have difficulty swallowing',
     'E_74': 'I have noticed a widespread redness in one or both eyes',
     'E_205': 'I suddenly have difficulty to open my mouth or have jaw pain when opening it',
     'E_63': 'I have difficulty articulating words',
     'E_128': 'I have felt like I was suffocating for a very short time with an inability to breathe or speak',
     'E_190': 'I have noticed that I produce more saliva than usual',
     'E_39': 'I have felt confused or disorientated lately',
     'E_212': 'I have noticed that the tone of my voice has become deeper, softer or hoarse',
     'E_206': 'I have painful mouth ulcers',
     'E_52': 'I have the perception of seeing two images of a single object seen overlapping or adjacent to each other',
     'E_203': 'I have intense coughing fits',
     'E_38': 'I have pain in my jaw',
     'E_172': 'I have a hard time opening/raising one or both eyelids',
     'E_84': 'I feel weakness in both arms and both legs',
     'E_90': 'My symptoms of muscle weakness increase with fatigue and stress',
     'E_211': 'I have vomited several times',
     'E_166': 'I vomitted after coughing',
     'E_112': 'My breathing is noisy after coughing spells',
     'E_178': 'I have noticed unusual bleeding or bruising',
     'E_152': 'The swelling locations are',
     'E_151': 'I have swelling in one or more areas of your body',
     'E_45': 'I have been coughing up blood',
     'E_194': 'I have noticed a high pitched sound when breathing in',
     'E_83': 'I have noticed weakness in my facial muscles and eyes',
     'E_157': 'I have recently had numbness, loss of sensation or tingling, in both arms and legs and around my mouth',
     'E_176': 'I have had paralysis in my limbs or in my face',
     'E_42': 'I have eaten something that I have an allergy to',
     'E_214': 'I have noticed a wheezing sound when I exhale',
     'E_150': 'I have been able to pass stools or gas since my symptoms increased',
     'E_32': 'I have a decrease in appetite',
     'E_221': 'My symptoms increase with coughing or an effort like lifting a weight',
     'E_202': 'I have a whooping cough',
     'E_219': 'My symptoms are more prominent at night',
     'E_196': 'I have had surgery within the last month',
     'E_170': 'I have severe itching in one or both eyes',
     'E_77': 'My cough produces colored or more abundant sputum than usual',
     'E_13': 'My symptoms have worsened over the last 2 weeks and progressively less effort is required to cause the symptoms',
     'E_14': 'I have chest pain even at rest',
     'E_169': 'My nose or the back of my throat is itchy',
     'E_177': 'I have recently had numbness, loss of sensation or tingling on my body',
     'E_175': 'I have noticed a generalized and vague discomfort with diffuse  muscle aches',
     'E_174': 'I have been unintentionally losing weight',
     'E_145': 'I have very long menstruation periods',
     'E_92': 'My cheeks suddenly turned red',
     'E_192': 'I feel that muscle spasms or soreness in my neck are keeping me from turning my head to one side',
     'E_188': 'I have pale stools and dark urine',
     'E_164': 'I feel my heart is beating very irregularly in a disorganized pattern',
     'E_193': 'I have annoying muscle spasms in my face/neck',
     'E_168': 'I have trouble keeping my tongue in my mouth',
     'E_180': 'I am unable to control the direction of my eyes',
     'E_67': 'I have bouts of choking or shortness of breath that wake me up at night',
     'E_78': 'I drink alcohol excessively',
     'E_146': 'I am taking a new oral anticoagulants',
     'E_171': 'I feel like I am detached from my own body or my surroundings',
     'E_111': 'I feel like I am dying',
     'E_182': 'I have greenish/yellowish nasal discharge',
     'E_103': 'I have lost my sense of smell',
     'E_23': 'I temporarily stop breathing while I am asleep',
     'E_105': 'I have had a heart attack',
     'E_108': 'I have a problem with poor blood circulation',
     'E_104': 'I take medications to treat high blood pressure',
     'E_79': 'I smoke cigarettes',
     'E_71': 'I am taking medications to treat high cholesterol',
     'E_41': 'I have been in contact with a person with similar symptoms in the past 2 weeks',
     'E_100': 'I currently take hormones',
     'E_69': 'I have diabetes',
     'E_167': 'I am pregnant',
     'E_115': 'I have had unprotected sex with more than one partner in the last 6 months',
     'E_70': 'I am significantly overweight compared to people of the same height as me',
     'E_10': 'I have recently taken anti-inflammatory drugs',
     'E_165': 'Some family members have had a pneumothorax',
     'E_8': 'I am currently undergo dialysis',
     'E_25': 'Some family members have been diagnosed with cluster headaches',
     'E_184': 'I take medications that dilates your blood vessels',
     'E_185': 'I have had a head trauma',
     'E_99': 'Some family members are known to have migraines',
     'E_107': 'I have had a stroke',
     'E_226': 'I am more likely to develop common allergies than the general population',
     'E_62': 'I regularly take stimulant drugs',
     'E_49': 'I work in a daycare',
     'E_95': "I have the Parkinson's disease",
     'E_37': 'I have a metastatic cancer',
     'E_153': 'I am being treated for osteoporosis',
     'E_124': 'I have had to use a bronchodilator in the past',
     'E_98': 'I have a hiatal hernia',
     'E_116': 'I have had a cold in the last 2 weeks',
     'E_48': 'I live with 4 or more people',
     'E_2': 'I am infected with the human immunodeficiency virus (HIV)',
     'E_227': 'I am immunosuppressed',
     'E_61': 'I am currently using intravenous drugs',
     'E_47': "I suffer from Crohn's disease or ulcerative colitis",
     'E_27': 'I have had a sexually transmitted infection',
     'E_143': 'I exercise regularly, 4 times per week or more',
     'E_191': 'I am a former smoker',
     'E_208': 'I am underweight',
     'E_126': 'I have liver cirrhosis',
     'E_189': 'I have had sexual intercourse with an HIV-positive partner in the past 12 months',
     'E_7': 'I have a poor diet',
     'E_24': 'I have had a diagnosis of anemia',
     'E_26': 'Some family members have been diagnosed with anemia',
     'E_113': 'I have chronic kidney failure',
     'E_160': 'I was born prematurely',
     'E_28': 'Some family members have been diagnosed with myasthenia gravis',
     'E_20': 'I have Rheumatoid Arthritis',
     'E_80': 'I have been diagnosed with depression',
     'E_40': 'I have been in contact with someone who has had whoooping cough',
     'E_0': 'I have recently had a viral infection',
     'E_1': 'I have recently been treated with an oral antibiotic for an ear infection',
     'E_34': 'I have an active cancer',
     'E_209': 'my vaccinations are up to date',
     'E_139': 'I have a known heart defect',
     'E_19': 'I have been diagnosed with hyperthyroidism',
     'E_31': 'I have severe Chronic Obstructive Pulmonary Disease',
     'E_22': 'I have a known issue with one of my heart valves',
     'E_60': 'I regularly consume energy drinks',
     'E_35': 'I regularly drink coffee or tea',
     'E_213': 'I have recently taken decongestants or substances that may have stimulant effects',
     'E_12': 'I have a known severe food allergy',
     'E_44': 'I take corticosteroids',
     'E_4': 'Some family members have had croup',
     'E_81': 'I suffer from chronic anxiety',
     'E_109': 'I have had deep vein thrombosis',
     'E_110': 'I have been unable to move or get up for more than 3 consecutive days within the last 4 weeks',
     'E_17': 'I am of Asian descent',
     'E_18': 'I have cystic fibrosis',
     'E_118': 'I have had pneumonia',
     'E_123': 'I have a chronic obstructive pulmonary disease',
     'E_207': 'I live in in a big city',
     'E_86': 'Some family members suffer from allergies, hay fever or eczema',
     'E_87': 'Some family members have asthma',
     'E_141': 'I have my first menstrual period before the age of 12',
     'E_11': 'I have breastfed one of my children for more than 9 months',
     'E_186': 'I have been diagnosed with obstructive sleep apnea',
     'E_106': 'I have heart failure',
     'E_158': 'I was diagnosed with a hormonal dysfunction',
     'E_187': 'I ate tuna and Swiss cheese before the reaction occurred',
     'E_6': 'I have chronic pancreatitis',
     'E_125': 'I have been diagnosed with gastroesophageal reflux',
     'E_21': 'I have had a spontaneous pneumothorax',
     'E_222': 'I am exposed to secondhand cigarette smoke on a daily basis',
     'E_15': 'I have taken some antipsychotic medications within the last 7 days',
     'E_147': 'I have been treated in hospital recently for nausea, agitation, intoxication or aggressive behavior and received medication via an intravenous or intramuscular route',
     'E_137': 'I have had surgery to remove lymph nodes',
     'E_149': 'I take a calcium channel blockers as medications',
     'E_197': 'I have a known kidney problem resulting in an inability to retain proteins',
     'E_3': 'I have had a pericarditis',
     'E_29': 'Some members of my immediate family have a psychiatric illness',
     'E_225': 'I have close family members who had a cardiovascular disease problem before the age of 50',
     'E_73': 'I have been in contact with anyone infected with the Ebola virus in the last month',
     'E_138': 'I suffer from fibromyalgia',
     'E_101': 'I have been hospitalized for an asthma attack in the past year',
     'E_46': 'I have had more than one asthma attack in the past year',
     'E_119': 'I have been diagnosed with chronic sinusitis',
     'E_72': 'I have had one or several flare ups of chronic obstructive pulmonary disease',
     'E_198': 'I work in agriculture',
     'E_200': 'I work in the mining sector',
     'E_199': 'I work in construction',
     'E_121': 'I have a deviated nasal septum',
     'E_120': 'I have polyps in my nose',
     'E_142': 'My mother suffers from asthma',
     'E_195': 'I live in the suburbs',
     'E_183': 'I live in a rural area',
     'E_224': 'Some family members have had lung cancer',
     'E_223': 'Some family members have been diagnosed with pancreatic cancer',
     'E_5': 'I have had fluid in your lungs',
     'E_204': 'I have recently travelled to'
}

# %%
meta_data = {
    "fr": [fr_evidence_2_statements, "trav1", "N", "AmerN"],    
    "en": [en_evidence_2_statements, "E_204", "V_10", "V_4"]
}

# %%
def pprintPatient(
    df, idx, cond_data, symp_data, evidence_2_statements, 
    travel_evidence, travel_negative_answer, default_location, filename=None
):
    age = df.iloc[idx]['AGE']
    sex = df.iloc[idx]['SEX']
    patho = df.iloc[idx]['PATHOLOGY']
    evidences = ast.literal_eval(df.iloc[idx]['EVIDENCES'])
    ddx = ast.literal_eval(df.iloc[idx]['DIFFERENTIAL_DIAGNOSIS'])
    geo = [a for a in evidences if a.startswith(f"{travel_evidence}_@_")]
    geo = geo[0][len(f"{travel_evidence}_@_"):] if len(geo) > 0 else default_location
    geo = default_location if geo == travel_negative_answer else geo
    geo = symp_data[travel_evidence]["value_meaning"][geo]["en"]
    
    str_ddx = []
    for i in range(len(ddx)):
        ddx[i][0] = cond_data[ddx[i][0]]['cond-name-eng']
        res = f"{ddx[i][0]}: {ddx[i][1]:.3f}"
        str_ddx.append(res)
    
    symp, atcd = {}, {}
    for evi in evidences:
        if not ("_@_" in evi):
            if symp_data[evi]["is_antecedent"]:
                atcd[evi] = True
            else:
                symp[evi] = True
        else:
            evi, val = evi.split("_@_")
            if evi == travel_evidence:
                continue
            l = symp.get(evi, [])
            l.append(val)
            symp[evi] = l
            

    if filename is not None:
        f = open(filename, 'a')
    else:
        f = sys.stdout

    enKey = "cond-name-eng"
    eol = ""
    print(f"Sex: {sex}, Age: {age}{eol}", file=f)
    print(f"Geographical region: {geo}{eol}", file=f)
    print(f"Pathology: {cond_data[patho][enKey]}{eol}", file=f)
    print(f"Symptoms:{eol}", file=f)
    print(f"---------{eol}", file=f)
    alist = sorted(symp.keys())
    for evi in alist:
        if isinstance(symp[evi], bool):
            print(f"\t - {evidence_2_statements[evi]}.{eol}", file=f)
        elif len(symp[evi]) > 1:
            print(f"\t - {evidence_2_statements[evi]}:{eol}", file=f)
            for val in symp[evi]:
                vtext = symp_data[evi]["value_meaning"][val]["en"]
                print(f"\t\t » {vtext}{eol}", file=f)
        else:
            val = symp[evi][0]
            if isinstance(symp_data[evi]["default_value"], (int, float)):
                val = int(val)
                if val != symp_data[evi]["default_value"]:
                    print(f"\t - {evidence_2_statements[evi]} {val}{eol}", file=f)
            elif "N" == symp_data[evi]["default_value"] and evi != travel_evidence:
                if val != symp_data[evi]["default_value"]:
                    print(f"\t - {evidence_2_statements[evi]}{eol}", file=f)
            elif val != symp_data[evi]["default_value"]:
                vtext = symp_data[evi]["value_meaning"][val]["en"]
                if symp_data[evi]["data_type"] == "M":
                    sep = ":\n\t\t » "
                else:
                    sep = " "         
                print(f"\t - {evidence_2_statements[evi]}{sep}{vtext}{eol}", file=f)
    
    print(f"Antecedents:{eol}", file=f)
          
    print(f"-----------{eol}", file=f)
    alist = sorted(atcd.keys())
    for evi in alist:
        print(f"\t - {evidence_2_statements[evi]}.{eol}", file=f)
            
    print(f"Differential diagnosis:{eol}", file=f)
    print(f"----------------------{eol}", file=f)
    ddx_string = ", ".join(str_ddx)
    print(f"{ddx_string}{eol}", file=f)
    
    print("\n##########################################################\n", file=f)

# %%
def pprintInteraction(
    df, cond_data, symp_data, evidence_2_statements, 
    travel_evidence, travel_negative_answer, default_location,
    action, diff, idx=0, showDiff=False, filename=None
):
    
    evidences = ast.literal_eval(df.iloc[idx]['EVIDENCES'])
    ddx = ast.literal_eval(df.iloc[idx]['DIFFERENTIAL_DIAGNOSIS'])
    geo = [a for a in evidences if a.startswith(f"{travel_evidence}_@_")]
    geo = geo[0][len(f"{travel_evidence}_@_"):] if len(geo) > 0 else default_location
    geo = default_location if geo == travel_negative_answer else geo
    geo = symp_data[travel_evidence]["value_meaning"][geo]["en"]
    age = df.iloc[idx]['AGE']
    sex = df.iloc[idx]['SEX']
    
    str_ddx = []
    for i in range(len(ddx)):
        ddx[i][0] = cond_data[ddx[i][0]]['cond-name-eng']
        res = f"{ddx[i][0]}: {ddx[i][1]:.3f}"
        str_ddx.append(res)
    
    symp, atcd = {}, {}
    for evi in evidences:
        if not ("_@_" in evi):
            if symp_data[evi]["is_antecedent"]:
                atcd[evi] = True
            else:
                symp[evi] = True
        else:
            evi, val = evi.split("_@_")
            if evi == travel_evidence:
                atcd[evi] = [val]
                continue
            l = symp.get(evi, [])
            l.append(val)
            symp[evi] = l
    
    dfa = pd.read_csv(action)
    df_diff = pd.read_csv(diff)
    
    actions = dfa.iloc[idx].tolist()
    all_ddx = df_diff.iloc[idx].tolist()
    
    index = sum([a!='None' for a in actions])
    all_ddx = [ast.literal_eval(all_ddx[i]) for i in range(index)]
    for i in range(len(all_ddx)):
        all_ddx[i] = [cond_data[a]['cond-name-eng'] for a in all_ddx[i]]
    ddx = all_ddx[index - 1]
    
    
    if filename is not None:
        f = open(filename, 'a')
    else:
        f = sys.stdout
    
    print(f"Sex: {sex}, Age: {age}", file=f)
    # print(f"Geographical region: {geo}", file=f)    
    for i in range(index):
        if i == 0:
            print(f"Initial evidence: \n\t {evidence_2_statements[actions[i]]}", file=f) 
        else:
            print(f"*Turn {i}:", file=f) 
            a = actions[i]
            q = symp_data[a]["question_en"]
            print(f"  Q: {q}", file=f)
            
            if (not (a in symp)) and (not (a in atcd)):
                o = "N" if symp_data[a]["data_type"] == "B" else (
                    symp_data[a]["default_value"] if isinstance(symp_data[a]["default_value"], (int, float))
                    else symp_data[a]["value_meaning"][symp_data[a]["default_value"]]["en"]
                )
                print(f"  A: {o}", file=f)
                 
            elif a in symp:
                if isinstance(symp[a], bool):
                    print("  A: Y", file=f)
                else:
                    print("  A:", file=f)
                    for o in symp[a]:
                        v = o if isinstance(symp_data[a]["default_value"], (int, float)) else symp_data[a]["value_meaning"][o]["en"]
                        print(f"\t * {v}", file=f)
            else:
                if isinstance(atcd[a], bool):
                    print("  A: Y", file=f)
                else:
                    for o in atcd[a]:
                        v = symp_data[a]["value_meaning"][o]["en"]
                        print(f"  A: {v}", file=f)
        if showDiff:
            ddxstr = ", ".join(all_ddx[i])
            if i==0:
                print(f"Differential diagnosis: \n\t {ddxstr}\n", file=f)
            else:
                print(f"  Differential diagnosis: \n\t{ddxstr}\n", file=f)
            
        if i == 0:             
            print("Agent inquiries:", file=f)
            print("---------------", file=f)
    
    if not showDiff:
        print("Predicted differential:", file=f)
        print("----------------------", file=f)
        ddxstr = ", ".join(ddx)
        print(ddxstr, file=f)
    print("Ground-truth differential:", file=f)
    print("-------------------------", file=f)
    ddx_string = ", ".join(str_ddx)
    print(f"{ddx_string}", file=f)
    
    print("\n##########################################################\n", file=f)

# %% [markdown]
# # Printing Patients

# %%
_, _, cond_data = load_json_data("../data/release_conditions.json", "condition_name")
_, _, symp_data = load_json_data("../data/release_evidences.json", "name")

# %%
filename = "../data/release_test_patients.zip"
df = pd.read_csv(filename)

# %%
df["DDX_LEN"] = df["DIFFERENTIAL_DIAGNOSIS"].apply(lambda x: len(ast.literal_eval(x)))

# %%
ddx_lt10_indices = df[df['DDX_LEN']<=10].index.tolist()
ddx_in10_20_indices = df[(df['DDX_LEN'] > 10) & (df['DDX_LEN'] <= 20)].index.tolist()
ddx_gt20_indices = df[df['DDX_LEN']>20].index.tolist()

# %%
# for the 20 patients
# - 10 within ddx indices with a number of entries between 1 and 10
# - 6 within ddx indices with a number of entries between 11 and 20
# - 4 within ddx indices with a number of entries greater than 20

# seed format: ddmmYYYY
seed = 22082022

np.random.seed(seed)

sub1 = np.random.choice(ddx_lt10_indices, size=10, replace=False).tolist()
sub2 = np.random.choice(ddx_in10_20_indices, size=6, replace=False).tolist()
sub3 = np.random.choice(ddx_gt20_indices, size=4, replace=False).tolist()

all_20_patient_indices = sub1 + sub2 + sub3

# %%
suffix = "Test"

# %%
ds_version="en"

# %%
for idx in all_20_patient_indices:
    pprintPatient(df, idx, cond_data, symp_data, *meta_data[ds_version], f"all_20_patients{suffix}.txt")

# %%
df2 = df.filter(items = all_20_patient_indices, axis=0).reset_index()

# %%
df2.to_csv(f"patientSample20{suffix}.csv", sep=",", index=False)

# %%
df2 = pd.read_csv(f"patientSample20{suffix}.csv")

# %%
for idx in range(len(df2)):
    pprintPatient(df2, idx, cond_data, symp_data, *meta_data[ds_version])
# Out:
# Sex: F, Age: 55
# Geographical region: North America
# Pathology: URTI
# Symptoms:
# ---------
# 	 - I have nasal congestion.
# 	 - I am coughing.
# 	 - I have had significantly increased sweating.
# 	 - I feel pain.
# 	 - The pain is:
# 		 » sensitive
# 		 » heavy
# 	 - The pain locations are:
# 		 » top of the head
# 		 » forehead
# 		 » temple(R)
# 	 - On a scale of 0-10, the pain intensity is 7
# 	 - On a scale of 0-10, the pain's location precision is 6
# 	 - On a scale of 0-10, the pace at which the pain appear is 3
# 	 - My cough produces colored or more abundant sputum than usual.
# 	 - I have fever.
# 	 - I have a sore throat.
# Antecedents:
# -----------
# 	 - I have been in contact with a person with similar symptoms in the past 2 weeks.
# 	 - I live with 4 or more people.
# 	 - I work in a daycare.
# Differential diagnosis:
# ----------------------
# URTI: 0.171, Bronchitis: 0.155, Influenza: 0.139, Pneumonia: 0.139, Bronchiectasis: 0.104, Tuberculosis: 0.095, HIV (initial infection): 0.061, Chronic rhinosinusitis: 0.057, Chagas: 0.042, Acute rhinosinusitis: 0.037
#
# ##########################################################
#
# Sex: F, Age: 63
# Geographical region: North America
# Pathology: Sarcoidosis
# Symptoms:
# ---------
# 	 - I have had vaginal discharge.
# 	 - I had an absence episode and lost consciousness.
# 	 - I feel pain.
# 	 - The pain is:
# 		 » sensitive
# 		 » burning
# 		 » sharp
# 	 - The pain locations are:
# 		 » finger (ring finger)(R)
# 		 » finger (ring finger)(L)
# 		 » finger (little finger)(R)
# 		 » finger (little finger)(L)
# 		 » shoulder(L)
# 	 - On a scale of 0-10, the pain intensity is 1
# 	 - On a scale of 0-10, the pace at which the pain appear is 3
# 	 - I have swollen and painful lymph nodes.
# Antecedents:
# -----------
# 	 - I work in agriculture.
# Differential diagnosis:
# ----------------------
# Sarcoidosis: 0.430, Possible NSTEMI / STEMI: 0.311, Unstable angina: 0.152, Stable angina: 0.107
#
# ##########################################################
#
# Sex: M, Age: 35
# Geographical region: North America
# Pathology: URTI
# Symptoms:
# ---------
# 	 - I have diffuse muscle pain.
# 	 - I have nasal congestion.
# 	 - I am coughing.
# 	 - I have had significantly increased sweating.
# 	 - I feel pain.
# 	 - The pain is:
# 		 » tedious
# 		 » heavy
# 	 - The pain locations are:
# 		 » forehead
# 		 » cheek(R)
# 		 » cheek(L)
# 		 » temple(R)
# 		 » temple(L)
# 	 - On a scale of 0-10, the pain intensity is 6
# 	 - On a scale of 0-10, the pain's location precision is 5
# 	 - On a scale of 0-10, the pace at which the pain appear is 5
# 	 - My cough produces colored or more abundant sputum than usual.
# 	 - I have fever.
# 	 - I have a sore throat.
# Antecedents:
# -----------
# 	 - I am exposed to secondhand cigarette smoke on a daily basis.
# 	 - I live with 4 or more people.
# 	 - I smoke cigarettes.
# Differential diagnosis:
# ----------------------
# URTI: 0.161, Influenza: 0.152, Pneumonia: 0.151, Bronchitis: 0.143, HIV (initial infection): 0.118, Tuberculosis: 0.081, Bronchiectasis: 0.069, Chronic rhinosinusitis: 0.053, Chagas: 0.038, Acute rhinosinusitis: 0.034
#
# ##########################################################
#
# Sex: F, Age: 18
# Geographical region: North America
# Pathology: Acute otitis media
# Symptoms:
# ---------
# 	 - I have nasal congestion.
# 	 - I feel pain.
# 	 - The pain is:
# 		 » sensitive
# 	 - The pain locations are:
# 		 » ear(R)
# 		 » ear(L)
# 	 - On a scale of 0-10, the pain intensity is 6
# 	 - On a scale of 0-10, the pain's location precision is 10
# 	 - On a scale of 0-10, the pace at which the pain appear is 2
# Antecedents:
# -----------
# Differential diagnosis:
# ----------------------
# Acute otitis media: 1.000
#
# ##########################################################
#
# Sex: M, Age: 31
# Geographical region: North America
# Pathology: Acute dystonic reactions
# Symptoms:
# ---------
# 	 - I have felt like I was suffocating for a very short time with an inability to breathe or speak.
# 	 - I have a hard time opening/raising one or both eyelids.
# 	 - I am unable to control the direction of my eyes.
# 	 - I have annoying muscle spasms in my face/neck.
# Antecedents:
# -----------
# 	 - I have taken some antipsychotic medications within the last 7 days.
# 	 - I regularly take stimulant drugs.
# Differential diagnosis:
# ----------------------
# Acute dystonic reactions: 0.616, Myasthenia gravis: 0.384
#
# ##########################################################
#
# Sex: M, Age: 33
# Geographical region: North America
# Pathology: Chronic rhinosinusitis
# Symptoms:
# ---------
# 	 - I have lost my sense of smell.
# 	 - I have greenish/yellowish nasal discharge.
# 	 - I am coughing.
# 	 - I feel pain.
# 	 - The pain is:
# 		 » burning
# 		 » sharp
# 	 - The pain locations are:
# 		 » mouth
# 		 » forehead
# 		 » cheek(R)
# 		 » cheek(L)
# 		 » nose
# 	 - On a scale of 0-10, the pain intensity is 2
# 	 - The pain radiates to these locations:
# 		 » back of head
# 		 » forehead
# 		 » nose
# 		 » temple(L)
# 	 - On a scale of 0-10, the pain's location precision is 2
# 	 - On a scale of 0-10, the pace at which the pain appear is 4
# Antecedents:
# -----------
# 	 - I have had a cold in the last 2 weeks.
# 	 - I have had pneumonia.
# 	 - I have polyps in my nose.
# 	 - I have a deviated nasal septum.
# 	 - I have had to use a bronchodilator in the past.
# 	 - I have been diagnosed with gastroesophageal reflux.
# 	 - I am more likely to develop common allergies than the general population.
# 	 - I smoke cigarettes.
# Differential diagnosis:
# ----------------------
# Acute rhinosinusitis: 0.206, Chronic rhinosinusitis: 0.192, Bronchitis: 0.169, Acute laryngitis: 0.120, Viral pharyngitis: 0.108, Cluster headache: 0.079, Chagas: 0.062, Anemia: 0.062
#
# ##########################################################
#
# Sex: F, Age: 2
# Geographical region: North America
# Pathology: Influenza
# Symptoms:
# ---------
# 	 - I have rashes.
# 	 - The color of the rash is pink
# 	 - On a scale of 0-10, the rash swelling is 2
# 	 - The regions affected by the rash are:
# 		 » back of the neck
# 		 » side of the neck(R)
# 	 - On a scale of 0-10, the pain intensity caused by the rash is 5
# 	 - The rash lesions are larger than 1cm Y
# 	 - On a scale of 0-10, the severity of the rash itching is 2
# 	 - I have diffuse muscle pain.
# 	 - I am coughing.
# 	 - I have had significantly increased sweating.
# 	 - I feel pain.
# 	 - The pain is:
# 		 » sensitive
# 		 » heavy
# 		 » exhausting
# 	 - The pain locations are:
# 		 » back of head
# 		 » back of the neck
# 		 » side of the neck(R)
# 		 » forehead
# 		 » occiput
# 	 - On a scale of 0-10, the pain intensity is 3
# 	 - On a scale of 0-10, the pain's location precision is 7
# 	 - On a scale of 0-10, the pace at which the pain appear is 2
# 	 - I have fever.
# 	 - I have a sore throat.
# Antecedents:
# -----------
# 	 - I am immunosuppressed.
# Differential diagnosis:
# ----------------------
# Pneumonia: 0.171, URTI: 0.165, Influenza: 0.160, Bronchitis: 0.146, HIV (initial infection): 0.127, Tuberculosis: 0.095, Chagas: 0.072, Scombroid food poisoning: 0.065
#
# ##########################################################
#
# Sex: M, Age: 43
# Geographical region: North America
# Pathology: Viral pharyngitis
# Symptoms:
# ---------
# 	 - I have nasal congestion.
# 	 - I feel pain.
# 	 - The pain is:
# 		 » sensitive
# 		 » burning
# 	 - The pain locations are:
# 		 » tonsil(R)
# 		 » tonsil(L)
# 		 » thyroid cartilage
# 		 » pharynx
# 	 - On a scale of 0-10, the pain intensity is 4
# 	 - On a scale of 0-10, the pain's location precision is 6
# 	 - On a scale of 0-10, the pace at which the pain appear is 4
# Antecedents:
# -----------
# 	 - I am immunosuppressed.
# 	 - I have been in contact with a person with similar symptoms in the past 2 weeks.
# 	 - I live with 4 or more people.
# 	 - I smoke cigarettes.
# Differential diagnosis:
# ----------------------
# Viral pharyngitis: 0.406, Possible NSTEMI / STEMI: 0.253, Acute laryngitis: 0.131, Unstable angina: 0.123, Stable angina: 0.087
#
# ##########################################################
#
# Sex: F, Age: 11
# Geographical region: North America
# Pathology: Chagas
# Symptoms:
# ---------
# 	 - I have nausea.
# 	 - I have been unintentionally losing weight.
# 	 - I feel pain.
# 	 - The pain is:
# 		 » tedious
# 		 » sensitive
# 		 » tugging
# 		 » a cramp
# 		 » sharp
# 		 » exhausting
# 	 - The pain locations are:
# 		 » cervical spine
# 		 » flank(R)
# 		 » forehead
# 		 » occiput
# 		 » temple(R)
# 	 - On a scale of 0-10, the pain intensity is 8
# 	 - On a scale of 0-10, the pain's location precision is 6
# 	 - On a scale of 0-10, the pace at which the pain appear is 2
# 	 - I have fever.
# Antecedents:
# -----------
# Differential diagnosis:
# ----------------------
# Chagas: 1.000
#
# ##########################################################
#
# Sex: F, Age: 31
# Geographical region: North America
# Pathology: Anemia
# Symptoms:
# ---------
# 	 - I have very long menstruation periods.
# 	 - My skin is much paler than usual.
# 	 - I noticed light red blood or blood clots in my stool.
# 	 - I feel pain.
# 	 - The pain is:
# 		 » sensitive
# 		 » exhausting
# 	 - The pain locations are:
# 		 » back of head
# 		 » forehead
# 		 » temple(L)
# 	 - On a scale of 0-10, the pain intensity is 4
# 	 - On a scale of 0-10, the pain's location precision is 5
# 	 - On a scale of 0-10, the pace at which the pain appear is 3
# 	 - I am experiencing shortness of breath or difficulty breathing in a significant way.
# 	 - I feel slightly dizzy or lightheaded.
# 	 - I constantly feel fatigued .
# Antecedents:
# -----------
# 	 - I am taking a new oral anticoagulants.
# 	 - I have had a diagnosis of anemia.
# 	 - I have a poor diet.
# Differential diagnosis:
# ----------------------
# Anemia: 0.215, Atrial fibrillation: 0.179, Myocarditis: 0.124, Acute pulmonary edema: 0.121, Guillain-Barré syndrome: 0.110, Cluster headache: 0.097, Acute dystonic reactions: 0.078, Myasthenia gravis: 0.078
#
# ##########################################################
#
# Sex: F, Age: 39
# Geographical region: North America
# Pathology: SLE
# Symptoms:
# ---------
# 	 - I have rashes.
# 	 - The color of the rash is red
# 	 - On a scale of 0-10, the rash swelling is 2
# 	 - The regions affected by the rash are:
# 		 » cheek(R)
# 		 » cheek(L)
# 	 - The rash lesions are larger than 1cm Y
# 	 - On a scale of 0-10, the severity of the rash itching is 2
# 	 - I feel pain.
# 	 - The pain is:
# 		 » sharp
# 	 - The pain locations are:
# 		 » back of the neck
# 		 » ankle(R)
# 		 » ankle(L)
# 		 » dorsal aspect of the wrist(L)
# 		 » shoulder(L)
# 	 - On a scale of 0-10, the pain intensity is 3
# 	 - On a scale of 0-10, the pain's location precision is 7
# 	 - On a scale of 0-10, the pace at which the pain appear is 4
# 	 - I am experiencing shortness of breath or difficulty breathing in a significant way.
# 	 - I constantly feel fatigued .
# Antecedents:
# -----------
# 	 - I have high blood pressure.
# 	 - I have had a pericarditis.
# Differential diagnosis:
# ----------------------
# SLE: 0.092, Pulmonary neoplasm: 0.085, Possible NSTEMI / STEMI: 0.083, Pulmonary embolism: 0.081, Pneumonia: 0.068, Anemia: 0.067, Guillain-Barré syndrome: 0.061, Atrial fibrillation: 0.058, Myocarditis: 0.048, Anaphylaxis: 0.043, Acute dystonic reactions: 0.043, Myasthenia gravis: 0.043, Pancreatic neoplasm: 0.041, Bronchiectasis: 0.040, Bronchitis: 0.034, Stable angina: 0.033, PSVT: 0.023, HIV (initial infection): 0.021, Tuberculosis: 0.020, Chagas: 0.015
#
# ##########################################################
#
# Sex: F, Age: 23
# Geographical region: North America
# Pathology: Anaphylaxis
# Symptoms:
# ---------
# 	 - I have rashes.
# 	 - The color of the rash is pink
# 	 - On a scale of 0-10, the rash swelling is 6
# 	 - The regions affected by the rash are:
# 		 » biceps(R)
# 		 » biceps(L)
# 		 » mouth
# 		 » thyroid cartilage
# 		 » ankle(R)
# 	 - On a scale of 0-10, the pain intensity caused by the rash is 2
# 	 - The rash lesions are larger than 1cm Y
# 	 - On a scale of 0-10, the severity of the rash itching is 10
# 	 - I have nausea.
# 	 - I have swelling in one or more areas of your body.
# 	 - The swelling locations are:
# 		 » forehead
# 		 » cheek(R)
# 		 » cheek(L)
# 		 » nose
# 	 - I lost consciousness.
# 	 - I have noticed a wheezing sound when I exhale.
# 	 - I have eaten something that I have an allergy to.
# 	 - I feel pain.
# 	 - The pain is:
# 		 » a knife stroke
# 	 - The pain locations are:
# 		 » flank(R)
# 		 » flank(L)
# 		 » pubis
# 		 » epigastric
# 	 - On a scale of 0-10, the pain intensity is 9
# 	 - On a scale of 0-10, the pain's location precision is 6
# 	 - On a scale of 0-10, the pace at which the pain appear is 4
# 	 - I feel like I am about to faint.
# Antecedents:
# -----------
# 	 - I am more likely to develop common allergies than the general population.
# Differential diagnosis:
# ----------------------
# Anaphylaxis: 0.133, Possible NSTEMI / STEMI: 0.097, GERD: 0.091, Localized edema: 0.089, Unstable angina: 0.089, Pulmonary embolism: 0.088, Boerhaave: 0.085, Panic attack: 0.068, Anemia: 0.065, PSVT: 0.059, Pericarditis: 0.048, Chagas: 0.046, Stable angina: 0.041
#
# ##########################################################
#
# Sex: F, Age: 56
# Geographical region: North America
# Pathology: Anaphylaxis
# Symptoms:
# ---------
# 	 - I have rashes.
# 	 - The color of the rash is pink
# 	 - On a scale of 0-10, the rash swelling is 1
# 	 - The regions affected by the rash are:
# 		 » biceps(R)
# 		 » mouth
# 		 » thyroid cartilage
# 		 » ankle(R)
# 		 » ankle(L)
# 	 - On a scale of 0-10, the pain intensity caused by the rash is 3
# 	 - The rash lesions are larger than 1cm Y
# 	 - On a scale of 0-10, the severity of the rash itching is 7
# 	 - I have swelling in one or more areas of your body.
# 	 - The swelling locations are:
# 		 » forehead
# 		 » cheek(R)
# 		 » cheek(L)
# 		 » nose
# 	 - I have diarrhea or an increase in stool frequency.
# 	 - I feel pain.
# 	 - The pain is:
# 		 » a knife stroke
# 		 » a cramp
# 		 » sharp
# 	 - The pain locations are:
# 		 » flank(R)
# 		 » iliac fossa(L)
# 		 » hypochondrium(R)
# 		 » hypochondrium(L)
# 		 » epigastric
# 	 - On a scale of 0-10, the pain intensity is 5
# 	 - On a scale of 0-10, the pain's location precision is 5
# 	 - On a scale of 0-10, the pace at which the pain appear is 3
# 	 - I am experiencing shortness of breath or difficulty breathing in a significant way.
# 	 - I feel like I am about to faint.
# Antecedents:
# -----------
# 	 - I have a known severe food allergy.
# Differential diagnosis:
# ----------------------
# Anaphylaxis: 0.085, GERD: 0.072, Unstable angina: 0.068, Stable angina: 0.064, Anemia: 0.062, Scombroid food poisoning: 0.059, Inguinal hernia: 0.059, Pancreatic neoplasm: 0.058, PSVT: 0.051, Panic attack: 0.051, Possible NSTEMI / STEMI: 0.051, Guillain-Barré syndrome: 0.048, Atrial fibrillation: 0.046, Acute pulmonary edema: 0.043, Chagas: 0.039, Myocarditis: 0.038, Pulmonary embolism: 0.036, Acute dystonic reactions: 0.034, Myasthenia gravis: 0.034
#
# ##########################################################
#
# Sex: F, Age: 56
# Geographical region: North America
# Pathology: Boerhaave
# Symptoms:
# ---------
# 	 - I have nausea.
# 	 - I have vomited several times.
# 	 - I feel pain.
# 	 - The pain is:
# 		 » haunting
# 		 » a knife stroke
# 		 » sickening
# 	 - The pain locations are:
# 		 » lower chest
# 		 » epigastric
# 	 - On a scale of 0-10, the pain intensity is 7
# 	 - The pain radiates to these locations:
# 		 » thoracic spine
# 		 » scapula(R)
# 	 - On a scale of 0-10, the pain's location precision is 5
# 	 - On a scale of 0-10, the pace at which the pain appear is 10
# 	 - I am experiencing shortness of breath or difficulty breathing in a significant way.
# Antecedents:
# -----------
# 	 - I drink alcohol excessively.
# Differential diagnosis:
# ----------------------
# Boerhaave: 0.149, Possible NSTEMI / STEMI: 0.145, GERD: 0.100, Anaphylaxis: 0.098, Guillain-Barré syndrome: 0.094, Atrial fibrillation: 0.090, Acute dystonic reactions: 0.067, Scombroid food poisoning: 0.061, Pericarditis: 0.055, Sarcoidosis: 0.054, Unstable angina: 0.049, PSVT: 0.036
#
# ##########################################################
#
# Sex: F, Age: 39
# Geographical region: North America
# Pathology: Bronchitis
# Symptoms:
# ---------
# 	 - I am coughing.
# 	 - My symptoms are more prominent at night.
# 	 - I feel pain.
# 	 - The pain is:
# 		 » burning
# 	 - The pain locations are:
# 		 » lower chest
# 		 » breast(L)
# 		 » posterior chest wall(L)
# 	 - On a scale of 0-10, the pain intensity is 2
# 	 - On a scale of 0-10, the pain's location precision is 3
# 	 - On a scale of 0-10, the pace at which the pain appear is 5
# 	 - My cough produces colored or more abundant sputum than usual.
# 	 - I have fever.
# 	 - I have a sore throat.
# Antecedents:
# -----------
# 	 - I smoke cigarettes.
# Differential diagnosis:
# ----------------------
# Bronchitis: 0.161, Pneumonia: 0.152, GERD: 0.119, URTI: 0.105, Possible NSTEMI / STEMI: 0.091, Tuberculosis: 0.087, Unstable angina: 0.085, Bronchiectasis: 0.074, Stable angina: 0.047, Boerhaave: 0.045, Chagas: 0.033
#
# ##########################################################
#
# Sex: M, Age: 65
# Geographical region: North America
# Pathology: Pericarditis
# Symptoms:
# ---------
# 	 - I feel palpitations.
# 	 - My symptoms worse when lying down and alleviated while sitting up.
# 	 - I feel pain.
# 	 - The pain is:
# 		 » a knife stroke
# 	 - The pain locations are:
# 		 » breast(R)
# 		 » breast(L)
# 		 » epigastric
# 	 - On a scale of 0-10, the pain intensity is 5
# 	 - The pain radiates to these locations:
# 		 » thoracic spine
# 		 » posterior chest wall(R)
# 		 » posterior chest wall(L)
# 	 - On a scale of 0-10, the pain's location precision is 2
# 	 - On a scale of 0-10, the pace at which the pain appear is 9
# 	 - I am experiencing shortness of breath or difficulty breathing in a significant way.
# Antecedents:
# -----------
# 	 - I have recently had a viral infection.
# 	 - I have had a pericarditis.
# Differential diagnosis:
# ----------------------
# Possible NSTEMI / STEMI: 0.121, Pericarditis: 0.116, GERD: 0.116, Myocarditis: 0.087, PSVT: 0.087, Guillain-Barré syndrome: 0.083, Atrial fibrillation: 0.076, Panic attack: 0.076, Anaphylaxis: 0.073, Scombroid food poisoning: 0.059, Acute dystonic reactions: 0.059, Sarcoidosis: 0.048
#
# ##########################################################
#
# Sex: F, Age: 41
# Geographical region: North America
# Pathology: Anaphylaxis
# Symptoms:
# ---------
# 	 - I have rashes.
# 	 - The color of the rash is pink
# 	 - On a scale of 0-10, the rash swelling is 2
# 	 - The regions affected by the rash are:
# 		 » back of the neck
# 		 » biceps(R)
# 		 » ankle(R)
# 		 » ankle(L)
# 		 » cervical spine
# 	 - On a scale of 0-10, the pain intensity caused by the rash is 1
# 	 - The rash lesions are larger than 1cm Y
# 	 - On a scale of 0-10, the severity of the rash itching is 8
# 	 - I have nausea.
# 	 - I have swelling in one or more areas of your body.
# 	 - The swelling locations are:
# 		 » forehead
# 		 » cheek(R)
# 		 » nose
# 	 - I have noticed a high pitched sound when breathing in.
# 	 - I have noticed a wheezing sound when I exhale.
# 	 - I have eaten something that I have an allergy to.
# 	 - I have diarrhea or an increase in stool frequency.
# 	 - I feel pain.
# 	 - The pain is:
# 		 » a knife stroke
# 		 » sharp
# 	 - The pain locations are:
# 		 » flank(L)
# 		 » hypochondrium(R)
# 		 » belly
# 		 » epigastric
# 	 - On a scale of 0-10, the pain intensity is 9
# 	 - On a scale of 0-10, the pain's location precision is 6
# 	 - On a scale of 0-10, the pace at which the pain appear is 8
# 	 - I am experiencing shortness of breath or difficulty breathing in a significant way.
# 	 - I feel like I am about to faint.
# Antecedents:
# -----------
# 	 - I have a known severe food allergy.
# Differential diagnosis:
# ----------------------
# Anaphylaxis: 0.077, Panic attack: 0.064, Bronchospasm / acute asthma exacerbation: 0.060, Unstable angina: 0.057, Boerhaave: 0.057, Acute pulmonary edema: 0.055, Possible NSTEMI / STEMI: 0.054, Epiglottitis: 0.047, Anemia: 0.047, GERD: 0.047, Larygospasm: 0.043, Stable angina: 0.042, Pancreatic neoplasm: 0.041, PSVT: 0.039, Pericarditis: 0.038, Guillain-Barré syndrome: 0.037, Chagas: 0.036, Atrial fibrillation: 0.035, Acute COPD exacerbation / infection: 0.033, Acute dystonic reactions: 0.026, Myasthenia gravis: 0.026, Pulmonary embolism: 0.020, HIV (initial infection): 0.019
#
# ##########################################################
#
# Sex: F, Age: 73
# Geographical region: North America
# Pathology: Acute pulmonary edema
# Symptoms:
# ---------
# 	 - I have swelling in one or more areas of your body.
# 	 - The swelling locations are:
# 		 » ankle(R)
# 		 » calf(R)
# 		 » calf(L)
# 		 » tibia(R)
# 		 » tibia(L)
# 	 - I have noticed a generalized and vague discomfort with diffuse  muscle aches.
# 	 - My symptoms worse when lying down and alleviated while sitting up.
# 	 - I have had significantly increased sweating.
# 	 - I feel pain.
# 	 - The pain is:
# 		 » tedious
# 		 » sensitive
# 		 » tugging
# 	 - The pain locations are:
# 		 » lower chest
# 		 » side of the chest(R)
# 		 » upper chest
# 		 » posterior chest wall(R)
# 		 » posterior chest wall(L)
# 	 - On a scale of 0-10, the pain intensity is 8
# 	 - The pain radiates to these locations:
# 		 » chin
# 		 » scapula(R)
# 		 » scapula(L)
# 		 » shoulder(R)
# 		 » shoulder(L)
# 	 - On a scale of 0-10, the pain's location precision is 6
# 	 - On a scale of 0-10, the pace at which the pain appear is 3
# 	 - I am experiencing shortness of breath or difficulty breathing in a significant way.
# 	 - I have bouts of choking or shortness of breath that wake me up at night.
# Antecedents:
# -----------
# 	 - I take medications to treat high blood pressure.
# 	 - I have had a heart attack.
# 	 - I have heart failure.
# 	 - I have had fluid in your lungs.
# 	 - I am currently undergo dialysis.
# Differential diagnosis:
# ----------------------
# Acute pulmonary edema: 0.083, Pericarditis: 0.069, Possible NSTEMI / STEMI: 0.068, Pulmonary embolism: 0.068, Panic attack: 0.067, Anaphylaxis: 0.059, GERD: 0.056, Myocarditis: 0.055, Boerhaave: 0.051, Spontaneous pneumothorax: 0.051, Pulmonary neoplasm: 0.045, Guillain-Barré syndrome: 0.043, Atrial fibrillation: 0.041, Chagas: 0.037, SLE: 0.034, Acute dystonic reactions: 0.030, Myasthenia gravis: 0.030, Anemia: 0.030, Sarcoidosis: 0.025, Unstable angina: 0.023, Scombroid food poisoning: 0.019, PSVT: 0.016, Stable angina: 0.001
#
# ##########################################################
#
# Sex: F, Age: 82
# Geographical region: North America
# Pathology: Bronchitis
# Symptoms:
# ---------
# 	 - I am coughing.
# 	 - I have noticed a wheezing sound when I exhale.
# 	 - My symptoms are more prominent at night.
# 	 - I feel pain.
# 	 - The pain is:
# 		 » burning
# 	 - The pain locations are:
# 		 » breast(R)
# 	 - On a scale of 0-10, the pain intensity is 4
# 	 - On a scale of 0-10, the pain's location precision is 7
# 	 - I am experiencing shortness of breath or difficulty breathing in a significant way.
# 	 - My cough produces colored or more abundant sputum than usual.
# Antecedents:
# -----------
# 	 - I have a chronic obstructive pulmonary disease.
# Differential diagnosis:
# ----------------------
# Acute COPD exacerbation / infection: 0.080, Bronchitis: 0.075, Pneumonia: 0.070, Bronchiectasis: 0.069, Pulmonary neoplasm: 0.061, Panic attack: 0.056, Possible NSTEMI / STEMI: 0.054, Unstable angina: 0.051, Pericarditis: 0.051, Spontaneous pneumothorax: 0.045, Myocarditis: 0.044, Stable angina: 0.042, Guillain-Barré syndrome: 0.040, Atrial fibrillation: 0.038, Spontaneous rib fracture: 0.034, Pulmonary embolism: 0.034, Acute dystonic reactions: 0.028, Myasthenia gravis: 0.028, Anemia: 0.028, Tuberculosis: 0.027, Sarcoidosis: 0.023, PSVT: 0.015, Chagas: 0.008
#
# ##########################################################
#
# Sex: M, Age: 49
# Geographical region: North America
# Pathology: Panic attack
# Symptoms:
# ---------
# 	 - I feel like I am dying.
# 	 - I feel palpitations.
# 	 - I have recently had numbness, loss of sensation or tingling, in both arms and legs and around my mouth.
# 	 - I feel like I am detached from my own body or my surroundings.
# 	 - I have recently had numbness, loss of sensation or tingling on my body.
# 	 - I have had significantly increased sweating.
# 	 - I feel pain.
# 	 - The pain is:
# 		 » a cramp
# 		 » sharp
# 	 - The pain locations are:
# 		 » side of the chest(R)
# 		 » flank(R)
# 		 » iliac fossa(R)
# 		 » hypochondrium(L)
# 		 » breast(L)
# 	 - On a scale of 0-10, the pain intensity is 6
# 	 - On a scale of 0-10, the pain's location precision is 7
# 	 - On a scale of 0-10, the pace at which the pain appear is 8
# 	 - I am experiencing shortness of breath or difficulty breathing in a significant way.
# 	 - I feel like choking or suffocating.
# 	 - I feel like I am about to faint.
# Antecedents:
# -----------
# 	 - I have had to use a bronchodilator in the past.
# 	 - I suffer from fibromyalgia.
# 	 - I feel anxious.
# 	 - I have had a head trauma.
# 	 - Some members of my immediate family have a psychiatric illness.
# 	 - I have been diagnosed with depression.
# Differential diagnosis:
# ----------------------
# Panic attack: 0.090, PSVT: 0.074, Possible NSTEMI / STEMI: 0.068, Guillain-Barré syndrome: 0.067, Spontaneous pneumothorax: 0.061, Pericarditis: 0.057, Acute pulmonary edema: 0.057, Anemia: 0.053, Anaphylaxis: 0.053, Unstable angina: 0.051, Pulmonary embolism: 0.048, Atrial fibrillation: 0.048, Stable angina: 0.040, GERD: 0.039, Inguinal hernia: 0.036, Scombroid food poisoning: 0.034, Acute dystonic reactions: 0.029, Myasthenia gravis: 0.029, Sarcoidosis: 0.024, Pancreatic neoplasm: 0.022, SLE: 0.013, Chagas: 0.009
#
# ##########################################################

# %% [markdown]
# # Printing Interactions

# %% [markdown]
# Let assume that you run a model that you trained on the patients in df2 using the provided run_eval.sh script. In addition to the metric file, the script will generate two other files:
#   * a csv file containing the differential predicted for each patient at each turn
#   * a csv file contating the actions (i.e., questions) asked by the agent at each turn.
#
# Let **diff_filepath** and  **action_filepath** be the filepaths to these two files, then the command below will print the interaction of first patient in the df (i.e., patient at index 0):

# %%
# action_filepath = "[path to the generated csv action file]"
# diff_filepath = "[path to the generated csv differential file]"
pprintInteraction(df2, cond_data, symp_data, *meta_data[ds_version], action_filepath, diff_filepath, 0, True)
# Out:
# Sex: F, Age: 55
# Initial evidence:
# 	 I have nasal congestion
# Differential diagnosis:
# 	 Bronchitis, Allergic sinusitis, Viral pharyngitis, Pneumonia, URTI, Bronchiectasis, Acute COPD exacerbation / infection, Chronic rhinosinusitis, Cluster headache, Acute rhinosinusitis, Tuberculosis, Acute otitis media, Unstable angina, Anemia, Bronchospasm / acute asthma exacerbation, Croup, Possible NSTEMI / STEMI, Pancreatic neoplasm, Pulmonary neoplasm, Spontaneous rib fracture, Influenza, Chagas, Pulmonary embolism, Stable angina, Atrial fibrillation, Epiglottitis, Anaphylaxis, Acute dystonic reactions, Boerhaave, Guillain-Barré syndrome, Sarcoidosis
#
# Agent inquiries:
# ---------------
# *Turn 1:
#   Q: Do you have any lesions, redness or problems on your skin that you believe are related to the condition you are consulting for?
#   A: N
#   Differential diagnosis:
# 	Allergic sinusitis, URTI, Pulmonary embolism, Chagas, Influenza, Anemia, Unstable angina, Cluster headache, Larygospasm, Pulmonary neoplasm, Epiglottitis, Croup, Possible NSTEMI / STEMI, Acute otitis media, Pneumonia, Anaphylaxis, Stable angina
#
# *Turn 2:
#   Q: Do you have pain somewhere, related to your reason for consulting?
#   A: Y
#   Differential diagnosis:
# 	Allergic sinusitis, Viral pharyngitis, URTI, Unstable angina, HIV (initial infection), Acute otitis media, Possible NSTEMI / STEMI, Pulmonary neoplasm, Anemia, Pulmonary embolism, Croup, Pancreatic neoplasm, Cluster headache, Bronchitis, Pneumonia, Acute COPD exacerbation / infection, Stable angina, Chagas, Bronchospasm / acute asthma exacerbation, Bronchiectasis, Tuberculosis, Spontaneous rib fracture, Anaphylaxis, Sarcoidosis, Localized edema, Influenza, SLE, Acute dystonic reactions, Larygospasm
#
# *Turn 3:
#   Q: Does the pain radiate to another location?
#   A:
# 	 * nowhere
#   Differential diagnosis:
# 	Allergic sinusitis, Viral pharyngitis, URTI, Unstable angina, HIV (initial infection), Cluster headache, Possible NSTEMI / STEMI, Pulmonary embolism, Anemia, Acute otitis media, Chagas, Stable angina, Influenza, Chronic rhinosinusitis, Croup, Epiglottitis, Pneumonia, Bronchiectasis, Tuberculosis, Pulmonary neoplasm, Bronchitis, Ebola, Acute laryngitis
#
# *Turn 4:
#   Q: Do you feel pain somewhere?
#   A:
# 	 * top of the head
# 	 * forehead
# 	 * temple(R)
#   Differential diagnosis:
# 	Bronchitis, Cluster headache, HIV (initial infection), Tuberculosis, Chagas, Anemia, URTI, Acute rhinosinusitis, Pneumonia, Chronic rhinosinusitis, Influenza
#
# *Turn 5:
#   Q: Characterize your pain:
#   A:
# 	 * sensitive
# 	 * heavy
#   Differential diagnosis:
# 	Influenza, Bronchitis, URTI, Tuberculosis, Chronic rhinosinusitis, Chagas, HIV (initial infection)
#
# *Turn 6:
#   Q: How precisely is the pain located?
#   A:
# 	 * 6
#   Differential diagnosis:
# 	Bronchitis, Influenza, URTI, Tuberculosis, HIV (initial infection), Chronic rhinosinusitis, Chagas
#
# *Turn 7:
#   Q: How intense is the pain?
#   A:
# 	 * 7
#   Differential diagnosis:
# 	Bronchitis, Influenza, URTI, Tuberculosis, HIV (initial infection), Chronic rhinosinusitis, Chagas
#
# *Turn 8:
#   Q: How fast did the pain appear?
#   A:
# 	 * 3
#   Differential diagnosis:
# 	Bronchitis, URTI, Influenza, Tuberculosis, HIV (initial infection), Chronic rhinosinusitis, Chagas
#
# *Turn 9:
#   Q: Do you live with 4 or more people?
#   A: Y
#   Differential diagnosis:
# 	Bronchitis, URTI, Influenza, Tuberculosis, Chronic rhinosinusitis, HIV (initial infection), Chagas
#
# *Turn 10:
#   Q: Do you have a sore throat?
#   A: Y
#   Differential diagnosis:
# 	URTI, Influenza, Bronchitis, HIV (initial infection), Tuberculosis, Chagas, Chronic rhinosinusitis, Acute rhinosinusitis
#
# *Turn 11:
#   Q: Do you have a cough that produces colored or more abundant sputum than usual?
#   A: Y
#   Differential diagnosis:
# 	URTI, Bronchitis, Influenza, Pneumonia, Bronchiectasis, Tuberculosis, HIV (initial infection), Chronic rhinosinusitis, Chagas, Acute rhinosinusitis
#
# *Turn 12:
#   Q: Are you exposed to secondhand cigarette smoke on a daily basis?
#   A: N
#   Differential diagnosis:
# 	URTI, Bronchitis, Influenza, Pneumonia, Bronchiectasis, Tuberculosis, HIV (initial infection), Chronic rhinosinusitis, Chagas
#
# *Turn 13:
#   Q: Have you been in contact with a person with similar symptoms in the past 2 weeks?
#   A: Y
#   Differential diagnosis:
# 	Bronchitis, URTI, Pneumonia, Influenza, Bronchiectasis, Tuberculosis, HIV (initial infection), Chronic rhinosinusitis, Chagas, Acute rhinosinusitis
#
# *Turn 14:
#   Q: Do you attend or work in a daycare?
#   A: Y
#   Differential diagnosis:
# 	Bronchitis, URTI, Pneumonia, Influenza, Bronchiectasis, Tuberculosis, HIV (initial infection), Chronic rhinosinusitis, Chagas, Acute rhinosinusitis
#
# *Turn 15:
#   Q: Do you have a cough?
#   A: Y
#   Differential diagnosis:
# 	Bronchitis, URTI, Pneumonia, Influenza, Bronchiectasis, Tuberculosis, HIV (initial infection), Chronic rhinosinusitis, Chagas, Acute rhinosinusitis
#
# *Turn 16:
#   Q: Do you have a fever (either felt or measured with a thermometer)?
#   A: Y
#   Differential diagnosis:
# 	Bronchitis, URTI, Pneumonia, Influenza, Bronchiectasis, Tuberculosis, HIV (initial infection), Chronic rhinosinusitis, Chagas, Acute rhinosinusitis
#
# *Turn 17:
#   Q: Do you have diffuse (widespread) muscle pain?
#   A: N
#   Differential diagnosis:
# 	Bronchitis, URTI, Pneumonia, Influenza, Bronchiectasis, Tuberculosis, HIV (initial infection), Chronic rhinosinusitis, Chagas
#
# *Turn 18:
#   Q: Have you had significantly increased sweating?
#   A: Y
#   Differential diagnosis:
# 	Bronchitis, URTI, Pneumonia, Influenza, Bronchiectasis, Tuberculosis, HIV (initial infection), Chronic rhinosinusitis, Chagas, Acute rhinosinusitis
#
# *Turn 19:
#   Q: Do you smoke cigarettes?
#   A: N
#   Differential diagnosis:
# 	Bronchitis, URTI, Pneumonia, Influenza, Bronchiectasis, Tuberculosis, HIV (initial infection), Chronic rhinosinusitis, Chagas, Acute rhinosinusitis
#
# Ground-truth differential:
# -------------------------
# URTI: 0.171, Bronchitis: 0.155, Influenza: 0.139, Pneumonia: 0.139, Bronchiectasis: 0.104, Tuberculosis: 0.095, HIV (initial infection): 0.061, Chronic rhinosinusitis: 0.057, Chagas: 0.042, Acute rhinosinusitis: 0.037
#
# ##########################################################

# %% [markdown]
# To generate the interaction of all the patients in df2, simply iterate over them as follows, to save the interactions in an ouput fileL

# %%
# action_filepath = "[path to the generated csv action file]"
# diff_filepath = "[path to the generated csv differential file]"
# output_filepath = "[path output file]"
for idx in range(len(df2)):
    pprintInteraction(df2, cond_data, symp_data, *meta_data[ds_version], action_filepath, diff_filepath, idx, False, output_filepath)

# %% [markdown]
# Or to print it on the console

# %%
# action_filepath = "[path to the generated csv action file]"
# diff_filepath = "[path to the generated csv differential file]"
for idx in range(len(df2)):
    pprintInteraction(df2, cond_data, symp_data, *meta_data[ds_version], action, diff, idx, False)
# Out:
# Sex: F, Age: 55
# Initial evidence:
# 	 I have nasal congestion
# Agent inquiries:
# ---------------
# *Turn 1:
#   Q: Do you have any lesions, redness or problems on your skin that you believe are related to the condition you are consulting for?
#   A: N
# *Turn 2:
#   Q: Do you have pain somewhere, related to your reason for consulting?
#   A: Y
# *Turn 3:
#   Q: Does the pain radiate to another location?
#   A:
# 	 * nowhere
# *Turn 4:
#   Q: Do you feel pain somewhere?
#   A:
# 	 * top of the head
# 	 * forehead
# 	 * temple(R)
# *Turn 5:
#   Q: Characterize your pain:
#   A:
# 	 * sensitive
# 	 * heavy
# *Turn 6:
#   Q: How precisely is the pain located?
#   A:
# 	 * 6
# *Turn 7:
#   Q: How intense is the pain?
#   A:
# 	 * 7
# *Turn 8:
#   Q: How fast did the pain appear?
#   A:
# 	 * 3
# *Turn 9:
#   Q: Do you live with 4 or more people?
#   A: Y
# *Turn 10:
#   Q: Do you have a sore throat?
#   A: Y
# *Turn 11:
#   Q: Do you have a cough that produces colored or more abundant sputum than usual?
#   A: Y
# *Turn 12:
#   Q: Are you exposed to secondhand cigarette smoke on a daily basis?
#   A: N
# *Turn 13:
#   Q: Have you been in contact with a person with similar symptoms in the past 2 weeks?
#   A: Y
# *Turn 14:
#   Q: Do you attend or work in a daycare?
#   A: Y
# *Turn 15:
#   Q: Do you have a cough?
#   A: Y
# *Turn 16:
#   Q: Do you have a fever (either felt or measured with a thermometer)?
#   A: Y
# *Turn 17:
#   Q: Do you have diffuse (widespread) muscle pain?
#   A: N
# *Turn 18:
#   Q: Have you had significantly increased sweating?
#   A: Y
# *Turn 19:
#   Q: Do you smoke cigarettes?
#   A: N
# Predicted differential:
# ----------------------
# Bronchitis, URTI, Pneumonia, Influenza, Bronchiectasis, Tuberculosis, HIV (initial infection), Chronic rhinosinusitis, Chagas, Acute rhinosinusitis
# Ground-truth differential:
# -------------------------
# URTI: 0.171, Bronchitis: 0.155, Influenza: 0.139, Pneumonia: 0.139, Bronchiectasis: 0.104, Tuberculosis: 0.095, HIV (initial infection): 0.061, Chronic rhinosinusitis: 0.057, Chagas: 0.042, Acute rhinosinusitis: 0.037
#
# ##########################################################
#
# Sex: F, Age: 63
# Initial evidence:
# 	 I have had vaginal discharge
# Agent inquiries:
# ---------------
# *Turn 1:
#   Q: Do you have any lesions, redness or problems on your skin that you believe are related to the condition you are consulting for?
#   A: N
# *Turn 2:
#   Q: Do you have pain somewhere, related to your reason for consulting?
#   A: Y
# *Turn 3:
#   Q: Does the pain radiate to another location?
#   A:
# 	 * nowhere
# *Turn 4:
#   Q: Do you feel pain somewhere?
#   A:
# 	 * finger (ring finger)(R)
# 	 * finger (ring finger)(L)
# 	 * finger (little finger)(R)
# 	 * finger (little finger)(L)
# 	 * shoulder(L)
# *Turn 5:
#   Q: Characterize your pain:
#   A:
# 	 * sensitive
# 	 * burning
# 	 * sharp
# *Turn 6:
#   Q: How precisely is the pain located?
#   A:
# 	 * 0
# *Turn 7:
#   Q: How intense is the pain?
#   A:
# 	 * 1
# *Turn 8:
#   Q: Do you work in agriculture?
#   A: Y
# *Turn 9:
#   Q: How fast did the pain appear?
#   A:
# 	 * 3
# *Turn 10:
#   Q: Are you significantly overweight compared to people of the same height as you?
#   A: N
# *Turn 11:
#   Q: Do you have swollen or painful lymph nodes?
#   A: Y
# *Turn 12:
#   Q: Are you experiencing shortness of breath or difficulty breathing in a significant way?
#   A: N
# *Turn 13:
#   Q: Have you noticed a diffuse (widespread) redness in one or both eyes?
#   A: N
# *Turn 14:
#   Q: Have you lost consciousness associated with violent and sustained muscle contractions or had an absence episode?
#   A: Y
# Predicted differential:
# ----------------------
# Sarcoidosis, Possible NSTEMI / STEMI, Unstable angina, Stable angina
# Ground-truth differential:
# -------------------------
# Sarcoidosis: 0.430, Possible NSTEMI / STEMI: 0.311, Unstable angina: 0.152, Stable angina: 0.107
#
# ##########################################################
#
# Sex: M, Age: 35
# Initial evidence:
# 	 I have fever
# Agent inquiries:
# ---------------
# *Turn 1:
#   Q: Do you have any lesions, redness or problems on your skin that you believe are related to the condition you are consulting for?
#   A: N
# *Turn 2:
#   Q: Do you have pain somewhere, related to your reason for consulting?
#   A: Y
# *Turn 3:
#   Q: Characterize your pain:
#   A:
# 	 * tedious
# 	 * heavy
# *Turn 4:
#   Q: Do you feel pain somewhere?
#   A:
# 	 * forehead
# 	 * cheek(R)
# 	 * cheek(L)
# 	 * temple(R)
# 	 * temple(L)
# *Turn 5:
#   Q: How precisely is the pain located?
#   A:
# 	 * 5
# *Turn 6:
#   Q: How intense is the pain?
#   A:
# 	 * 6
# *Turn 7:
#   Q: How fast did the pain appear?
#   A:
# 	 * 5
# *Turn 8:
#   Q: Do you have nasal congestion or a clear runny nose?
#   A: Y
# *Turn 9:
#   Q: Do you live with 4 or more people?
#   A: Y
# *Turn 10:
#   Q: Are you exposed to secondhand cigarette smoke on a daily basis?
#   A: Y
# *Turn 11:
#   Q: Do you have a cough?
#   A: Y
# *Turn 12:
#   Q: Do you have diffuse (widespread) muscle pain?
#   A: Y
# *Turn 13:
#   Q: Do you have a sore throat?
#   A: Y
# *Turn 14:
#   Q: Have you been in contact with a person with similar symptoms in the past 2 weeks?
#   A: N
# *Turn 15:
#   Q: Have you had significantly increased sweating?
#   A: Y
# *Turn 16:
#   Q: Do you attend or work in a daycare?
#   A: N
# *Turn 17:
#   Q: Do you smoke cigarettes?
#   A: Y
# *Turn 18:
#   Q: Do you have a cough that produces colored or more abundant sputum than usual?
#   A: Y
# Predicted differential:
# ----------------------
# Pneumonia, Influenza, Bronchitis, URTI, HIV (initial infection), Tuberculosis, Bronchiectasis, Chronic rhinosinusitis, Chagas, Acute rhinosinusitis
# Ground-truth differential:
# -------------------------
# URTI: 0.161, Influenza: 0.152, Pneumonia: 0.151, Bronchitis: 0.143, HIV (initial infection): 0.118, Tuberculosis: 0.081, Bronchiectasis: 0.069, Chronic rhinosinusitis: 0.053, Chagas: 0.038, Acute rhinosinusitis: 0.034
#
# ##########################################################
#
# Sex: F, Age: 18
# Initial evidence:
# 	 I feel pain
# Agent inquiries:
# ---------------
# *Turn 1:
#   Q: Do you have any lesions, redness or problems on your skin that you believe are related to the condition you are consulting for?
#   A: N
# *Turn 2:
#   Q: Does the pain radiate to another location?
#   A:
# 	 * nowhere
# *Turn 3:
#   Q: Do you feel pain somewhere?
#   A:
# 	 * ear(R)
# 	 * ear(L)
# *Turn 4:
#   Q: Characterize your pain:
#   A:
# 	 * sensitive
# *Turn 5:
#   Q: How precisely is the pain located?
#   A:
# 	 * 10
# *Turn 6:
#   Q: How intense is the pain?
#   A:
# 	 * 6
# *Turn 7:
#   Q: How fast did the pain appear?
#   A:
# 	 * 2
# *Turn 8:
#   Q: Are you currently being treated or have you recently been treated with an oral antibiotic for an ear infection?
#   A: N
# *Turn 9:
#   Q: Are you more irritable or has your mood been very unstable recently?
#   A: N
# *Turn 10:
#   Q: Are your vaccinations up to date?
#   A: N
# *Turn 11:
#   Q: Do you have nasal congestion or a clear runny nose?
#   A: Y
# *Turn 12:
#   Q: Do you have a fever (either felt or measured with a thermometer)?
#   A: N
# *Turn 13:
#   Q: Do you have a cough?
#   A: N
# Predicted differential:
# ----------------------
# Acute otitis media
# Ground-truth differential:
# -------------------------
# Acute otitis media: 1.000
#
# ##########################################################
#
# Sex: M, Age: 31
# Initial evidence:
# 	 I am unable to control the direction of my eyes
# Agent inquiries:
# ---------------
# *Turn 1:
#   Q: Do you have swelling in one or more areas of your body?
#   A: N
# *Turn 2:
#   Q: Do you have any lesions, redness or problems on your skin that you believe are related to the condition you are consulting for?
#   A: N
# *Turn 3:
#   Q: Do you have pain somewhere, related to your reason for consulting?
#   A: N
# *Turn 4:
#   Q: Do you have a hard time opening/raising one or both eyelids?
#   A: Y
# *Turn 5:
#   Q: Are you experiencing shortness of breath or difficulty breathing in a significant way?
#   A: N
# *Turn 6:
#   Q: Do you have annoying muscle spasms in your face, neck or any other part of your body?
#   A: Y
# *Turn 7:
#   Q: Have you started or taken any antipsychotic medication within the last 7 days?
#   A: Y
# *Turn 8:
#   Q: Do you regularly take stimulant drugs?
#   A: Y
# *Turn 9:
#   Q: Have you been treated in hospital recently for nausea, agitation, intoxication or aggressive behavior and received medication via an intravenous or intramuscular route?
#   A: N
# *Turn 10:
#   Q: Do you suddenly have difficulty or an inability to open your mouth or have jaw pain when opening it?
#   A: N
# *Turn 11:
#   Q: Do you feel that muscle spasms or soreness in your neck are keeping you from turning your head to one side?
#   A: N
# *Turn 12:
#   Q: Do you have trouble keeping your tongue in your mouth?
#   A: N
# *Turn 13:
#   Q: Have you ever felt like you were suffocating for a very short time associated with inability to breathe or speak?
#   A: Y
# Predicted differential:
# ----------------------
# Acute dystonic reactions, Myasthenia gravis
# Ground-truth differential:
# -------------------------
# Acute dystonic reactions: 0.616, Myasthenia gravis: 0.384
#
# ##########################################################
#
# Sex: M, Age: 33
# Initial evidence:
# 	 I feel pain
# Agent inquiries:
# ---------------
# *Turn 1:
#   Q: Do you have swelling in one or more areas of your body?
#   A: N
# *Turn 2:
#   Q: Do you have any lesions, redness or problems on your skin that you believe are related to the condition you are consulting for?
#   A: N
# *Turn 3:
#   Q: Does the pain radiate to another location?
#   A:
# 	 * back of head
# 	 * forehead
# 	 * nose
# 	 * temple(L)
# *Turn 4:
#   Q: Characterize your pain:
#   A:
# 	 * burning
# 	 * sharp
# *Turn 5:
#   Q: Do you feel pain somewhere?
#   A:
# 	 * mouth
# 	 * forehead
# 	 * cheek(R)
# 	 * cheek(L)
# 	 * nose
# *Turn 6:
#   Q: How precisely is the pain located?
#   A:
# 	 * 2
# *Turn 7:
#   Q: How intense is the pain?
#   A:
# 	 * 2
# *Turn 8:
#   Q: How fast did the pain appear?
#   A:
# 	 * 4
# *Turn 9:
#   Q: Do you have asthma or have you ever had to use a bronchodilator in the past?
#   A: Y
# *Turn 10:
#   Q: Do you have polyps in your nose?
#   A: Y
# *Turn 11:
#   Q: Do you have a cough?
#   A: Y
# *Turn 12:
#   Q: Are you more likely to develop common allergies than the general population?
#   A: Y
# *Turn 13:
#   Q: Have you ever had pneumonia?
#   A: Y
# *Turn 14:
#   Q: Have you ever been diagnosed with gastroesophageal reflux?
#   A: Y
# *Turn 15:
#   Q: Do you have a deviated nasal septum?
#   A: Y
# *Turn 16:
#   Q: Do you smoke cigarettes?
#   A: Y
# *Turn 17:
#   Q: Do you have greenish or yellowish nasal discharge?
#   A: Y
# *Turn 18:
#   Q: Have you had a cold in the last 2 weeks?
#   A: Y
# *Turn 19:
#   Q: Have you lost your sense of smell?
#   A: Y
# *Turn 20:
#   Q: Do you have a fever (either felt or measured with a thermometer)?
#   A: N
# *Turn 21:
#   Q: Do you have nasal congestion or a clear runny nose?
#   A: N
# Predicted differential:
# ----------------------
# Acute rhinosinusitis, Chronic rhinosinusitis, Bronchitis, Acute laryngitis, Viral pharyngitis, Cluster headache, Chagas, Anemia
# Ground-truth differential:
# -------------------------
# Acute rhinosinusitis: 0.206, Chronic rhinosinusitis: 0.192, Bronchitis: 0.169, Acute laryngitis: 0.120, Viral pharyngitis: 0.108, Cluster headache: 0.079, Chagas: 0.062, Anemia: 0.062
#
# ##########################################################
#
# Sex: F, Age: 2
# Initial evidence:
# 	 I am coughing
# Agent inquiries:
# ---------------
# *Turn 1:
#   Q: Do you have any lesions, redness or problems on your skin that you believe are related to the condition you are consulting for?
#   A: Y
# *Turn 2:
#   Q: What color is the rash?
#   A:
# 	 * pink
# *Turn 3:
#   Q: Do you have pain somewhere, related to your reason for consulting?
#   A: Y
# *Turn 4:
#   Q: Where is the affected region located?
#   A:
# 	 * back of the neck
# 	 * side of the neck(R)
# *Turn 5:
#   Q: Characterize your pain:
#   A:
# 	 * sensitive
# 	 * heavy
# 	 * exhausting
# *Turn 6:
#   Q: How precisely is the pain located?
#   A:
# 	 * 7
# *Turn 7:
#   Q: How intense is the pain?
#   A:
# 	 * 3
# *Turn 8:
#   Q: Is the rash swollen?
#   A:
# 	 * 2
# *Turn 9:
#   Q: How intense is the pain caused by the rash?
#   A:
# 	 * 5
# *Turn 10:
#   Q: How severe is the itching?
#   A:
# 	 * 2
# *Turn 11:
#   Q: How fast did the pain appear?
#   A:
# 	 * 2
# *Turn 12:
#   Q: Is the lesion (or are the lesions) larger than 1cm?
#   A:
# 	 * Y
# *Turn 13:
#   Q: Do you feel pain somewhere?
#   A:
# 	 * back of head
# 	 * back of the neck
# 	 * side of the neck(R)
# 	 * forehead
# 	 * occiput
# *Turn 14:
#   Q: Do you have a fever (either felt or measured with a thermometer)?
#   A: Y
# *Turn 15:
#   Q: Have you had significantly increased sweating?
#   A: Y
# *Turn 16:
#   Q: Do you feel so tired that you are unable to do your usual activities or are you stuck in your bed all day long?
#   A: N
# *Turn 17:
#   Q: Do you smoke cigarettes?
#   A: N
# *Turn 18:
#   Q: Do you have nasal congestion or a clear runny nose?
#   A: N
# *Turn 19:
#   Q: Have you had chills or shivers?
#   A: N
# *Turn 20:
#   Q: Are you immunosuppressed?
#   A: Y
# *Turn 21:
#   Q: Do you have diffuse (widespread) muscle pain?
#   A: Y
# *Turn 22:
#   Q: Do you have a sore throat?
#   A: Y
# *Turn 23:
#   Q: Have you recently had a loss of appetite or do you get full more quickly then usually?
#   A: N
# *Turn 24:
#   Q: Do you have severe Chronic Obstructive Pulmonary Disease (COPD)?
#   A: N
# *Turn 25:
#   Q: Do you have a chronic obstructive pulmonary disease (COPD)?
#   A: N
# Predicted differential:
# ----------------------
# Pneumonia, Influenza, Bronchitis, URTI, HIV (initial infection), Tuberculosis, Chagas, Scombroid food poisoning, Acute otitis media, Anaphylaxis
# Ground-truth differential:
# -------------------------
# Pneumonia: 0.171, URTI: 0.165, Influenza: 0.160, Bronchitis: 0.146, HIV (initial infection): 0.127, Tuberculosis: 0.095, Chagas: 0.072, Scombroid food poisoning: 0.065
#
# ##########################################################
#
# Sex: M, Age: 43
# Initial evidence:
# 	 I have nasal congestion
# Agent inquiries:
# ---------------
# *Turn 1:
#   Q: Do you have any lesions, redness or problems on your skin that you believe are related to the condition you are consulting for?
#   A: N
# *Turn 2:
#   Q: Do you have swelling in one or more areas of your body?
#   A: N
# *Turn 3:
#   Q: Do you have pain somewhere, related to your reason for consulting?
#   A: Y
# *Turn 4:
#   Q: Does the pain radiate to another location?
#   A:
# 	 * nowhere
# *Turn 5:
#   Q: Do you feel pain somewhere?
#   A:
# 	 * tonsil(R)
# 	 * tonsil(L)
# 	 * thyroid cartilage
# 	 * pharynx
# *Turn 6:
#   Q: Characterize your pain:
#   A:
# 	 * sensitive
# 	 * burning
# *Turn 7:
#   Q: How precisely is the pain located?
#   A:
# 	 * 6
# *Turn 8:
#   Q: How intense is the pain?
#   A:
# 	 * 4
# *Turn 9:
#   Q: How fast did the pain appear?
#   A:
# 	 * 4
# *Turn 10:
#   Q: Do you smoke cigarettes?
#   A: Y
# *Turn 11:
#   Q: Have you been in contact with a person with similar symptoms in the past 2 weeks?
#   A: Y
# *Turn 12:
#   Q: Do you have a cough?
#   A: N
# *Turn 13:
#   Q: Do you attend or work in a daycare?
#   A: N
# *Turn 14:
#   Q: Do you live with 4 or more people?
#   A: Y
# *Turn 15:
#   Q: Do you have a fever (either felt or measured with a thermometer)?
#   A: N
# *Turn 16:
#   Q: Are you immunosuppressed?
#   A: Y
# Predicted differential:
# ----------------------
# Viral pharyngitis, Possible NSTEMI / STEMI, Unstable angina, Acute laryngitis, Stable angina
# Ground-truth differential:
# -------------------------
# Viral pharyngitis: 0.406, Possible NSTEMI / STEMI: 0.253, Acute laryngitis: 0.131, Unstable angina: 0.123, Stable angina: 0.087
#
# ##########################################################
#
# Sex: F, Age: 11
# Initial evidence:
# 	 I have nausea
# Agent inquiries:
# ---------------
# *Turn 1:
#   Q: Do you have any lesions, redness or problems on your skin that you believe are related to the condition you are consulting for?
#   A: N
# *Turn 2:
#   Q: Do you have pain somewhere, related to your reason for consulting?
#   A: Y
# *Turn 3:
#   Q: Do you have swelling in one or more areas of your body?
#   A: N
# *Turn 4:
#   Q: Does the pain radiate to another location?
#   A:
# 	 * nowhere
# *Turn 5:
#   Q: Do you feel pain somewhere?
#   A:
# 	 * cervical spine
# 	 * flank(R)
# 	 * forehead
# 	 * occiput
# 	 * temple(R)
# *Turn 6:
#   Q: Characterize your pain:
#   A:
# 	 * tedious
# 	 * sensitive
# 	 * tugging
# 	 * a cramp
# 	 * sharp
# 	 * exhausting
# *Turn 7:
#   Q: How precisely is the pain located?
#   A:
# 	 * 6
# *Turn 8:
#   Q: How intense is the pain?
#   A:
# 	 * 8
# *Turn 9:
#   Q: How fast did the pain appear?
#   A:
# 	 * 2
# *Turn 10:
#   Q: Have you noticed any new fatigue, generalized and vague discomfort, diffuse (widespread) muscle aches or a change in your general well-being related to your consultation today?
#   A: N
# *Turn 11:
#   Q: Do you have swollen or painful lymph nodes?
#   A: N
# *Turn 12:
#   Q: Have you traveled out of the country in the last 4 weeks?
#   A: N
# *Turn 13:
#   Q: Do you have a fever (either felt or measured with a thermometer)?
#   A: Y
# *Turn 14:
#   Q: Are you experiencing shortness of breath or difficulty breathing in a significant way?
#   A: N
# *Turn 15:
#   Q: Have you had diarrhea or an increase in stool frequency?
#   A: N
# Predicted differential:
# ----------------------
# Chagas
# Ground-truth differential:
# -------------------------
# Chagas: 1.000
#
# ##########################################################
#
# Sex: F, Age: 31
# Initial evidence:
# 	 My skin is much paler than usual
# Agent inquiries:
# ---------------
# *Turn 1:
#   Q: Do you have pain somewhere, related to your reason for consulting?
#   A: Y
# *Turn 2:
#   Q: Do you have any lesions, redness or problems on your skin that you believe are related to the condition you are consulting for?
#   A: N
# *Turn 3:
#   Q: Characterize your pain:
#   A:
# 	 * sensitive
# 	 * exhausting
# *Turn 4:
#   Q: Do you feel pain somewhere?
#   A:
# 	 * back of head
# 	 * forehead
# 	 * temple(L)
# *Turn 5:
#   Q: How precisely is the pain located?
#   A:
# 	 * 5
# *Turn 6:
#   Q: How intense is the pain?
#   A:
# 	 * 4
# *Turn 7:
#   Q: Are you experiencing shortness of breath or difficulty breathing in a significant way?
#   A: Y
# *Turn 8:
#   Q: Are you taking any new oral anticoagulants ((NOACs)?
#   A: Y
# *Turn 9:
#   Q: How fast did the pain appear?
#   A:
# 	 * 3
# *Turn 10:
#   Q: Do you have a poor diet?
#   A: Y
# *Turn 11:
#   Q: Have you ever had a diagnosis of anemia?
#   A: Y
# *Turn 12:
#   Q: Do you have chronic kidney failure?
#   A: N
# *Turn 13:
#   Q: Have you noticed light red blood or blood clots in your stool?
#   A: Y
# *Turn 14:
#   Q: Do you have any family members who have been diagnosed with anemia?
#   A: N
# *Turn 15:
#   Q: Is your BMI less than 18.5, or are you underweight?
#   A: N
# *Turn 16:
#   Q: Do you think you are pregnant or are you currently pregnant?
#   A: N
# *Turn 17:
#   Q: Have you traveled out of the country in the last 4 weeks?
#   A: N
# *Turn 18:
#   Q: Do you feel so tired that you are unable to do your usual activities or are you stuck in your bed all day long?
#   A: N
# *Turn 19:
#   Q: Do you have very abundant or very long menstruation periods?
#   A: Y
# *Turn 20:
#   Q: Do you feel lightheaded and dizzy or do you feel like you are about to faint?
#   A: N
# *Turn 21:
#   Q: Have you recently had stools that were black (like coal)?
#   A: N
# *Turn 22:
#   Q: Do you feel slightly dizzy or lightheaded?
#   A: Y
# *Turn 23:
#   Q: Do you constantly feel fatigued or do you have non-restful sleep?
#   A: Y
# *Turn 24:
#   Q: Do you have a sore throat?
#   A: N
# *Turn 25:
#   Q: Are you exposed to secondhand cigarette smoke on a daily basis?
#   A: N
# Predicted differential:
# ----------------------
# Anemia, Myocarditis, Acute pulmonary edema, Guillain-Barré syndrome, Cluster headache, Acute dystonic reactions, Myasthenia gravis, Pulmonary neoplasm, Atrial fibrillation
# Ground-truth differential:
# -------------------------
# Anemia: 0.215, Atrial fibrillation: 0.179, Myocarditis: 0.124, Acute pulmonary edema: 0.121, Guillain-Barré syndrome: 0.110, Cluster headache: 0.097, Acute dystonic reactions: 0.078, Myasthenia gravis: 0.078
#
# ##########################################################
#
# Sex: F, Age: 39
# Initial evidence:
# 	 I feel pain
# Agent inquiries:
# ---------------
# *Turn 1:
#   Q: Do you have any lesions, redness or problems on your skin that you believe are related to the condition you are consulting for?
#   A: Y
# *Turn 2:
#   Q: What color is the rash?
#   A:
# 	 * red
# *Turn 3:
#   Q: Characterize your pain:
#   A:
# 	 * sharp
# *Turn 4:
#   Q: Do you feel pain somewhere?
#   A:
# 	 * back of the neck
# 	 * ankle(R)
# 	 * ankle(L)
# 	 * dorsal aspect of the wrist(L)
# 	 * shoulder(L)
# *Turn 5:
#   Q: Where is the affected region located?
#   A:
# 	 * cheek(R)
# 	 * cheek(L)
# *Turn 6:
#   Q: How precisely is the pain located?
#   A:
# 	 * 7
# *Turn 7:
#   Q: How intense is the pain?
#   A:
# 	 * 3
# *Turn 8:
#   Q: How severe is the itching?
#   A:
# 	 * 2
# *Turn 9:
#   Q: Is the rash swollen?
#   A:
# 	 * 2
# *Turn 10:
#   Q: How fast did the pain appear?
#   A:
# 	 * 4
# *Turn 11:
#   Q: Is the lesion (or are the lesions) larger than 1cm?
#   A:
# 	 * Y
# *Turn 12:
#   Q: Are you experiencing shortness of breath or difficulty breathing in a significant way?
#   A: Y
# *Turn 13:
#   Q: Did you have your first menstrual period before the age of 12?
#   A: N
# *Turn 14:
#   Q: Are you consulting because you have high blood pressure?
#   A: Y
# *Turn 15:
#   Q: Do you have painful mouth ulcers or sores?
#   A: N
# *Turn 16:
#   Q: Do you constantly feel fatigued or do you have non-restful sleep?
#   A: Y
# *Turn 17:
#   Q: Do you smoke cigarettes?
#   A: N
# *Turn 18:
#   Q: Have you ever had a pericarditis?
#   A: Y
# Predicted differential:
# ----------------------
# SLE, Possible NSTEMI / STEMI, Anemia, Guillain-Barré syndrome, Bronchiectasis, Atrial fibrillation, Acute dystonic reactions, Pulmonary embolism, Myocarditis, Pneumonia, Myasthenia gravis, Pulmonary neoplasm, Anaphylaxis, Pancreatic neoplasm, Bronchitis, Scombroid food poisoning, PSVT, Stable angina, Chagas
# Ground-truth differential:
# -------------------------
# SLE: 0.092, Pulmonary neoplasm: 0.085, Possible NSTEMI / STEMI: 0.083, Pulmonary embolism: 0.081, Pneumonia: 0.068, Anemia: 0.067, Guillain-Barré syndrome: 0.061, Atrial fibrillation: 0.058, Myocarditis: 0.048, Anaphylaxis: 0.043, Acute dystonic reactions: 0.043, Myasthenia gravis: 0.043, Pancreatic neoplasm: 0.041, Bronchiectasis: 0.040, Bronchitis: 0.034, Stable angina: 0.033, PSVT: 0.023, HIV (initial infection): 0.021, Tuberculosis: 0.020, Chagas: 0.015
#
# ##########################################################
#
# Sex: F, Age: 23
# Initial evidence:
# 	 I have swelling in one or more areas of your body
# Agent inquiries:
# ---------------
# *Turn 1:
#   Q: Do you have pain somewhere, related to your reason for consulting?
#   A: Y
# *Turn 2:
#   Q: Does the pain radiate to another location?
#   A:
# 	 * nowhere
# *Turn 3:
#   Q: Do you have any lesions, redness or problems on your skin that you believe are related to the condition you are consulting for?
#   A: Y
# *Turn 4:
#   Q: What color is the rash?
#   A:
# 	 * pink
# *Turn 5:
#   Q: Characterize your pain:
#   A:
# 	 * a knife stroke
# *Turn 6:
#   Q: Do you feel pain somewhere?
#   A:
# 	 * flank(R)
# 	 * flank(L)
# 	 * pubis
# 	 * epigastric
# *Turn 7:
#   Q: Where is the affected region located?
#   A:
# 	 * biceps(R)
# 	 * biceps(L)
# 	 * mouth
# 	 * thyroid cartilage
# 	 * ankle(R)
# *Turn 8:
#   Q: How precisely is the pain located?
#   A:
# 	 * 6
# *Turn 9:
#   Q: How intense is the pain?
#   A:
# 	 * 9
# *Turn 10:
#   Q: Is the rash swollen?
#   A:
# 	 * 6
# *Turn 11:
#   Q: How severe is the itching?
#   A:
# 	 * 10
# *Turn 12:
#   Q: How fast did the pain appear?
#   A:
# 	 * 4
# *Turn 13:
#   Q: How intense is the pain caused by the rash?
#   A:
# 	 * 2
# *Turn 14:
#   Q: Is the lesion (or are the lesions) larger than 1cm?
#   A:
# 	 * Y
# *Turn 15:
#   Q: Have you been in contact with or ate something that you have an allergy to?
#   A: Y
# *Turn 16:
#   Q: Are you experiencing shortness of breath or difficulty breathing in a significant way?
#   A: N
# *Turn 17:
#   Q: Where is the swelling located?
#   A:
# 	 * forehead
# 	 * cheek(R)
# 	 * cheek(L)
# 	 * nose
# *Turn 18:
#   Q: Do you have a known severe food allergy?
#   A: N
# *Turn 19:
#   Q: Have you noticed a high pitched sound when breathing in?
#   A: N
# *Turn 20:
#   Q: Are you feeling nauseous or do you feel like vomiting?
#   A: Y
# *Turn 21:
#   Q: Do you feel lightheaded and dizzy or do you feel like you are about to faint?
#   A: Y
# *Turn 22:
#   Q: Are you more likely to develop common allergies than the general population?
#   A: Y
# *Turn 23:
#   Q: Have you had diarrhea or an increase in stool frequency?
#   A: N
# *Turn 24:
#   Q: Did you lose consciousness?
#   A: Y
# *Turn 25:
#   Q: Have you noticed a wheezing sound when you exhale?
#   A: Y
# Predicted differential:
# ----------------------
# Anaphylaxis, Localized edema, GERD, Boerhaave, Pulmonary embolism, Panic attack, Possible NSTEMI / STEMI, PSVT, Unstable angina, Inguinal hernia, Anemia, Pericarditis, Chagas, Stable angina, HIV (initial infection)
# Ground-truth differential:
# -------------------------
# Anaphylaxis: 0.133, Possible NSTEMI / STEMI: 0.097, GERD: 0.091, Localized edema: 0.089, Unstable angina: 0.089, Pulmonary embolism: 0.088, Boerhaave: 0.085, Panic attack: 0.068, Anemia: 0.065, PSVT: 0.059, Pericarditis: 0.048, Chagas: 0.046, Stable angina: 0.041
#
# ##########################################################
#
# Sex: F, Age: 56
# Initial evidence:
# 	 I have diarrhea or an increase in stool frequency
# Agent inquiries:
# ---------------
# *Turn 1:
#   Q: Do you have any lesions, redness or problems on your skin that you believe are related to the condition you are consulting for?
#   A: Y
# *Turn 2:
#   Q: Do you have swelling in one or more areas of your body?
#   A: Y
# *Turn 3:
#   Q: Do you have pain somewhere, related to your reason for consulting?
#   A: Y
# *Turn 4:
#   Q: Where is the affected region located?
#   A:
# 	 * biceps(R)
# 	 * mouth
# 	 * thyroid cartilage
# 	 * ankle(R)
# 	 * ankle(L)
# *Turn 5:
#   Q: What color is the rash?
#   A:
# 	 * pink
# *Turn 6:
#   Q: Do you feel pain somewhere?
#   A:
# 	 * flank(R)
# 	 * iliac fossa(L)
# 	 * hypochondrium(R)
# 	 * hypochondrium(L)
# 	 * epigastric
# *Turn 7:
#   Q: Characterize your pain:
#   A:
# 	 * a knife stroke
# 	 * a cramp
# 	 * sharp
# *Turn 8:
#   Q: How intense is the pain?
#   A:
# 	 * 5
# *Turn 9:
#   Q: How precisely is the pain located?
#   A:
# 	 * 5
# *Turn 10:
#   Q: Is the rash swollen?
#   A:
# 	 * 1
# *Turn 11:
#   Q: How severe is the itching?
#   A:
# 	 * 7
# *Turn 12:
#   Q: How fast did the pain appear?
#   A:
# 	 * 3
# *Turn 13:
#   Q: How intense is the pain caused by the rash?
#   A:
# 	 * 3
# *Turn 14:
#   Q: Is the lesion (or are the lesions) larger than 1cm?
#   A:
# 	 * Y
# *Turn 15:
#   Q: Have you been in contact with or ate something that you have an allergy to?
#   A: N
# *Turn 16:
#   Q: Are you experiencing shortness of breath or difficulty breathing in a significant way?
#   A: Y
# *Turn 17:
#   Q: Do you have a known severe food allergy?
#   A: Y
# *Turn 18:
#   Q: Where is the swelling located?
#   A:
# 	 * forehead
# 	 * cheek(R)
# 	 * cheek(L)
# 	 * nose
# *Turn 19:
#   Q: Have you noticed a high pitched sound when breathing in?
#   A: N
# *Turn 20:
#   Q: Do you feel lightheaded and dizzy or do you feel like you are about to faint?
#   A: Y
# *Turn 21:
#   Q: Are you feeling nauseous or do you feel like vomiting?
#   A: N
# *Turn 22:
#   Q: Are you more likely to develop common allergies than the general population?
#   A: N
# *Turn 23:
#   Q: Did you lose consciousness?
#   A: N
# *Turn 24:
#   Q: Have you noticed a wheezing sound when you exhale?
#   A: N
# *Turn 25:
#   Q: Did you have your first menstrual period before the age of 12?
#   A: N
# *Turn 26:
#   Q: Do you feel out of breath with minimal physical effort?
#   A: N
# *Turn 27:
#   Q: Do your lesions peel off?
#   A:
# 	 * N
# Predicted differential:
# ----------------------
# Anaphylaxis, Scombroid food poisoning, Panic attack, GERD, Acute pulmonary edema, Pancreatic neoplasm, PSVT, Inguinal hernia, Stable angina, Possible NSTEMI / STEMI, Anemia, Unstable angina, Myocarditis, Guillain-Barré syndrome, Pericarditis, Atrial fibrillation, Pulmonary embolism, Acute dystonic reactions, Chagas, Myasthenia gravis
# Ground-truth differential:
# -------------------------
# Anaphylaxis: 0.085, GERD: 0.072, Unstable angina: 0.068, Stable angina: 0.064, Anemia: 0.062, Scombroid food poisoning: 0.059, Inguinal hernia: 0.059, Pancreatic neoplasm: 0.058, PSVT: 0.051, Panic attack: 0.051, Possible NSTEMI / STEMI: 0.051, Guillain-Barré syndrome: 0.048, Atrial fibrillation: 0.046, Acute pulmonary edema: 0.043, Chagas: 0.039, Myocarditis: 0.038, Pulmonary embolism: 0.036, Acute dystonic reactions: 0.034, Myasthenia gravis: 0.034
#
# ##########################################################
#
# Sex: F, Age: 56
# Initial evidence:
# 	 I have nausea
# Agent inquiries:
# ---------------
# *Turn 1:
#   Q: Do you have any lesions, redness or problems on your skin that you believe are related to the condition you are consulting for?
#   A: N
# *Turn 2:
#   Q: Do you have pain somewhere, related to your reason for consulting?
#   A: Y
# *Turn 3:
#   Q: Does the pain radiate to another location?
#   A:
# 	 * thoracic spine
# 	 * scapula(R)
# *Turn 4:
#   Q: Do you feel pain somewhere?
#   A:
# 	 * lower chest
# 	 * epigastric
# *Turn 5:
#   Q: Characterize your pain:
#   A:
# 	 * haunting
# 	 * a knife stroke
# 	 * sickening
# *Turn 6:
#   Q: How precisely is the pain located?
#   A:
# 	 * 5
# *Turn 7:
#   Q: How intense is the pain?
#   A:
# 	 * 7
# *Turn 8:
#   Q: Have you recently thrown up blood or something resembling coffee beans?
#   A: N
# *Turn 9:
#   Q: Do you drink alcohol excessively or do you have an addiction to alcohol?
#   A: Y
# *Turn 10:
#   Q: How fast did the pain appear?
#   A:
# 	 * 10
# *Turn 11:
#   Q: Have you vomited several times or have you made several efforts to vomit?
#   A: Y
# *Turn 12:
#   Q: Are you experiencing shortness of breath or difficulty breathing in a significant way?
#   A: Y
# Predicted differential:
# ----------------------
# Possible NSTEMI / STEMI, Boerhaave, Guillain-Barré syndrome, GERD, Atrial fibrillation, Anaphylaxis, Acute dystonic reactions, Unstable angina, Scombroid food poisoning, Myasthenia gravis, Anemia, Sarcoidosis, Pancreatic neoplasm, Pericarditis, Chagas, PSVT, SLE, Panic attack
# Ground-truth differential:
# -------------------------
# Boerhaave: 0.149, Possible NSTEMI / STEMI: 0.145, GERD: 0.100, Anaphylaxis: 0.098, Guillain-Barré syndrome: 0.094, Atrial fibrillation: 0.090, Acute dystonic reactions: 0.067, Scombroid food poisoning: 0.061, Pericarditis: 0.055, Sarcoidosis: 0.054, Unstable angina: 0.049, PSVT: 0.036
#
# ##########################################################
# Sex: F, Age: 39
# Initial evidence:
# 	 I have fever
# Agent inquiries:
# ---------------
# *Turn 1:
#   Q: Do you have pain somewhere, related to your reason for consulting?
#   A: Y
# *Turn 2:
#   Q: Does the pain radiate to another location?
#   A:
# 	 * nowhere
# *Turn 3:
#   Q: Do you have any lesions, redness or problems on your skin that you believe are related to the condition you are consulting for?
#   A: N
# *Turn 4:
#   Q: Do you feel pain somewhere?
#   A:
# 	 * lower chest
# 	 * breast(L)
# 	 * posterior chest wall(L)
# *Turn 5:
#   Q: Characterize your pain:
#   A:
# 	 * burning
# *Turn 6:
#   Q: How precisely is the pain located?
#   A:
# 	 * 3
# *Turn 7:
#   Q: How intense is the pain?
#   A:
# 	 * 2
# *Turn 8:
#   Q: Are you experiencing shortness of breath or difficulty breathing in a significant way?
#   A: N
# *Turn 9:
#   Q: How fast did the pain appear?
#   A:
# 	 * 5
# *Turn 10:
#   Q: Do you have a cough?
#   A: Y
# *Turn 11:
#   Q: Do you have a chronic obstructive pulmonary disease (COPD)?
#   A: N
# *Turn 12:
#   Q: Do you have a cough that produces colored or more abundant sputum than usual?
#   A: Y
# *Turn 13:
#   Q: Have you had a cold in the last 2 weeks?
#   A: N
# *Turn 14:
#   Q: Have you noticed a wheezing sound when you exhale?
#   A: N
# *Turn 15:
#   Q: Do you have nasal congestion or a clear runny nose?
#   A: N
# *Turn 16:
#   Q: Are your symptoms more prominent at night?
#   A: Y
# *Turn 17:
#   Q: Do you have a sore throat?
#   A: Y
# *Turn 18:
#   Q: Do you smoke cigarettes?
#   A: Y
# Predicted differential:
# ----------------------
# Bronchitis, Pneumonia, GERD, Bronchiectasis, Tuberculosis, URTI, Possible NSTEMI / STEMI, Unstable angina, Boerhaave, Stable angina, Chagas
# Ground-truth differential:
# -------------------------
# Bronchitis: 0.161, Pneumonia: 0.152, GERD: 0.119, URTI: 0.105, Possible NSTEMI / STEMI: 0.091, Tuberculosis: 0.087, Unstable angina: 0.085, Bronchiectasis: 0.074, Stable angina: 0.047, Boerhaave: 0.045, Chagas: 0.033
#
# ##########################################################
#
# Sex: M, Age: 65
# Initial evidence:
# 	 My symptoms worse when lying down and alleviated while sitting up
# Agent inquiries:
# ---------------
# *Turn 1:
#   Q: Do you have swelling in one or more areas of your body?
#   A: N
# *Turn 2:
#   Q: Do you have any lesions, redness or problems on your skin that you believe are related to the condition you are consulting for?
#   A: N
# *Turn 3:
#   Q: Do you have pain somewhere, related to your reason for consulting?
#   A: Y
# *Turn 4:
#   Q: Does the pain radiate to another location?
#   A:
# 	 * thoracic spine
# 	 * posterior chest wall(R)
# 	 * posterior chest wall(L)
# *Turn 5:
#   Q: Characterize your pain:
#   A:
# 	 * a knife stroke
# *Turn 6:
#   Q: How precisely is the pain located?
#   A:
# 	 * 2
# *Turn 7:
#   Q: Do you feel pain somewhere?
#   A:
# 	 * breast(R)
# 	 * breast(L)
# 	 * epigastric
# *Turn 8:
#   Q: How intense is the pain?
#   A:
# 	 * 5
# *Turn 9:
#   Q: How fast did the pain appear?
#   A:
# 	 * 9
# *Turn 10:
#   Q: Have you recently had a viral infection?
#   A: Y
# *Turn 11:
#   Q: Do you have pain that is increased when you breathe in deeply?
#   A: N
# *Turn 12:
#   Q: Have you ever had a pericarditis?
#   A: Y
# *Turn 13:
#   Q: Are you experiencing shortness of breath or difficulty breathing in a significant way?
#   A: Y
# *Turn 14:
#   Q: Do you feel your heart is beating fast (racing), irregularly (missing a beat) or do you feel palpitations?
#   A: Y
# Predicted differential:
# ----------------------
# Pericarditis, Possible NSTEMI / STEMI, GERD, PSVT, Myocarditis, Panic attack, Atrial fibrillation, Acute pulmonary edema, Guillain-Barré syndrome, Acute dystonic reactions, Scombroid food poisoning, Sarcoidosis, Anaphylaxis, SLE, Myasthenia gravis
# Ground-truth differential:
# -------------------------
# Possible NSTEMI / STEMI: 0.121, Pericarditis: 0.116, GERD: 0.116, Myocarditis: 0.087, PSVT: 0.087, Guillain-Barré syndrome: 0.083, Atrial fibrillation: 0.076, Panic attack: 0.076, Anaphylaxis: 0.073, Scombroid food poisoning: 0.059, Acute dystonic reactions: 0.059, Sarcoidosis: 0.048
#
# ##########################################################
#
# Sex: F, Age: 41
# Initial evidence:
# 	 I have noticed a wheezing sound when I exhale
# Agent inquiries:
# ---------------
# *Turn 1:
#   Q: Do you have any lesions, redness or problems on your skin that you believe are related to the condition you are consulting for?
#   A: Y
# *Turn 2:
#   Q: Do you have pain somewhere, related to your reason for consulting?
#   A: Y
# *Turn 3:
#   Q: What color is the rash?
#   A:
# 	 * pink
# *Turn 4:
#   Q: Characterize your pain:
#   A:
# 	 * a knife stroke
# 	 * sharp
# *Turn 5:
#   Q: Where is the affected region located?
#   A:
# 	 * back of the neck
# 	 * biceps(R)
# 	 * ankle(R)
# 	 * ankle(L)
# 	 * cervical spine
# *Turn 6:
#   Q: Do you feel pain somewhere?
#   A:
# 	 * flank(L)
# 	 * hypochondrium(R)
# 	 * belly
# 	 * epigastric
# *Turn 7:
#   Q: How precisely is the pain located?
#   A:
# 	 * 6
# *Turn 8:
#   Q: How intense is the pain?
#   A:
# 	 * 9
# *Turn 9:
#   Q: Is the rash swollen?
#   A:
# 	 * 2
# *Turn 10:
#   Q: How severe is the itching?
#   A:
# 	 * 8
# *Turn 11:
#   Q: How fast did the pain appear?
#   A:
# 	 * 8
# *Turn 12:
#   Q: How intense is the pain caused by the rash?
#   A:
# 	 * 1
# *Turn 13:
#   Q: Do you have swelling in one or more areas of your body?
#   A: Y
# *Turn 14:
#   Q: Is the lesion (or are the lesions) larger than 1cm?
#   A:
# 	 * Y
# *Turn 15:
#   Q: Have you been in contact with or ate something that you have an allergy to?
#   A: Y
# *Turn 16:
#   Q: Do you have a known severe food allergy?
#   A: Y
# *Turn 17:
#   Q: Are you experiencing shortness of breath or difficulty breathing in a significant way?
#   A: Y
# *Turn 18:
#   Q: Where is the swelling located?
#   A:
# 	 * forehead
# 	 * cheek(R)
# 	 * nose
# *Turn 19:
#   Q: Have you noticed a high pitched sound when breathing in?
#   A: Y
# *Turn 20:
#   Q: Do you feel lightheaded and dizzy or do you feel like you are about to faint?
#   A: Y
# *Turn 21:
#   Q: Are you more likely to develop common allergies than the general population?
#   A: N
# *Turn 22:
#   Q: Are you feeling nauseous or do you feel like vomiting?
#   A: Y
# *Turn 23:
#   Q: Did you lose consciousness?
#   A: N
# *Turn 24:
#   Q: Do you have a chronic obstructive pulmonary disease (COPD)?
#   A: N
# *Turn 25:
#   Q: Have you had diarrhea or an increase in stool frequency?
#   A: Y
# Predicted differential:
# ----------------------
# Anaphylaxis, Panic attack, Boerhaave, Unstable angina, Acute pulmonary edema, GERD, Bronchospasm / acute asthma exacerbation, Pancreatic neoplasm, Possible NSTEMI / STEMI, Anemia, Epiglottitis, Larygospasm, PSVT, Guillain-Barré syndrome, Atrial fibrillation, Stable angina, Chagas, HIV (initial infection), Pulmonary embolism, Acute COPD exacerbation / infection, Pericarditis, Acute dystonic reactions, Myasthenia gravis
# Ground-truth differential:
# -------------------------
# Anaphylaxis: 0.077, Panic attack: 0.064, Bronchospasm / acute asthma exacerbation: 0.060, Unstable angina: 0.057, Boerhaave: 0.057, Acute pulmonary edema: 0.055, Possible NSTEMI / STEMI: 0.054, Epiglottitis: 0.047, Anemia: 0.047, GERD: 0.047, Larygospasm: 0.043, Stable angina: 0.042, Pancreatic neoplasm: 0.041, PSVT: 0.039, Pericarditis: 0.038, Guillain-Barré syndrome: 0.037, Chagas: 0.036, Atrial fibrillation: 0.035, Acute COPD exacerbation / infection: 0.033, Acute dystonic reactions: 0.026, Myasthenia gravis: 0.026, Pulmonary embolism: 0.020, HIV (initial infection): 0.019
#
# ##########################################################
#
# Sex: F, Age: 73
# Initial evidence:
# 	 I have bouts of choking or shortness of breath that wake me up at night
# Agent inquiries:
# ---------------
# *Turn 1:
#   Q: Do you have swelling in one or more areas of your body?
#   A: Y
# *Turn 2:
#   Q: Do you have any lesions, redness or problems on your skin that you believe are related to the condition you are consulting for?
#   A: N
# *Turn 3:
#   Q: Do you have pain somewhere, related to your reason for consulting?
#   A: Y
# *Turn 4:
#   Q: Does the pain radiate to another location?
#   A:
# 	 * chin
# 	 * scapula(R)
# 	 * scapula(L)
# 	 * shoulder(R)
# 	 * shoulder(L)
# *Turn 5:
#   Q: Characterize your pain:
#   A:
# 	 * tedious
# 	 * sensitive
# 	 * tugging
# *Turn 6:
#   Q: How precisely is the pain located?
#   A:
# 	 * 6
# *Turn 7:
#   Q: How intense is the pain?
#   A:
# 	 * 8
# *Turn 8:
#   Q: How fast did the pain appear?
#   A:
# 	 * 3
# *Turn 9:
#   Q: Have you ever had a heart attack or do you have angina (chest pain)?
#   A: Y
# *Turn 10:
#   Q: Do you have heart failure?
#   A: Y
# *Turn 11:
#   Q: Do you have high blood pressure or do you take medications to treat high blood pressure?
#   A: Y
# *Turn 12:
#   Q: Have you ever had fluid in your lungs?
#   A: Y
# *Turn 13:
#   Q: Where is the swelling located?
#   A:
# 	 * ankle(R)
# 	 * calf(R)
# 	 * calf(L)
# 	 * tibia(R)
# 	 * tibia(L)
# *Turn 14:
#   Q: Do you have symptoms that are increased with physical exertion but alleviated with rest?
#   A: N
# *Turn 15:
#   Q: Do you feel pain somewhere?
#   A:
# 	 * lower chest
# 	 * side of the chest(R)
# 	 * upper chest
# 	 * posterior chest wall(R)
# 	 * posterior chest wall(L)
# *Turn 16:
#   Q: Do you currently undergo dialysis?
#   A: Y
# *Turn 17:
#   Q: Do you feel your heart is beating very irregularly or in a disorganized pattern?
#   A: N
# *Turn 18:
#   Q: Are you experiencing shortness of breath or difficulty breathing in a significant way?
#   A: Y
# *Turn 19:
#   Q: Are your symptoms worse when lying down and alleviated while sitting up?
#   A: Y
# *Turn 20:
#   Q: Have you noticed any new fatigue, generalized and vague discomfort, diffuse (widespread) muscle aches or a change in your general well-being related to your consultation today?
#   A: Y
# *Turn 21:
#   Q: Have you had significantly increased sweating?
#   A: Y
# Predicted differential:
# ----------------------
# Acute pulmonary edema, Pericarditis, Possible NSTEMI / STEMI, Panic attack, Pulmonary embolism, Anaphylaxis, GERD, Myocarditis, Atrial fibrillation, SLE, Boerhaave, Spontaneous pneumothorax, Pulmonary neoplasm, Guillain-Barré syndrome, Acute dystonic reactions, Chagas, Sarcoidosis, Myasthenia gravis, Anemia, PSVT, Scombroid food poisoning, Unstable angina
# Ground-truth differential:
# -------------------------
# Acute pulmonary edema: 0.083, Pericarditis: 0.069, Possible NSTEMI / STEMI: 0.068, Pulmonary embolism: 0.068, Panic attack: 0.067, Anaphylaxis: 0.059, GERD: 0.056, Myocarditis: 0.055, Boerhaave: 0.051, Spontaneous pneumothorax: 0.051, Pulmonary neoplasm: 0.045, Guillain-Barré syndrome: 0.043, Atrial fibrillation: 0.041, Chagas: 0.037, SLE: 0.034, Acute dystonic reactions: 0.030, Myasthenia gravis: 0.030, Anemia: 0.030, Sarcoidosis: 0.025, Unstable angina: 0.023, Scombroid food poisoning: 0.019, PSVT: 0.016, Stable angina: 0.001
#
# ##########################################################
#
# Sex: F, Age: 82
# Initial evidence:
# 	 My symptoms are more prominent at night
# Agent inquiries:
# ---------------
# *Turn 1:
#   Q: Do you have any lesions, redness or problems on your skin that you believe are related to the condition you are consulting for?
#   A: N
# *Turn 2:
#   Q: Do you have pain somewhere, related to your reason for consulting?
#   A: Y
# *Turn 3:
#   Q: Does the pain radiate to another location?
#   A:
# 	 * nowhere
# *Turn 4:
#   Q: Do you feel pain somewhere?
#   A:
# 	 * breast(R)
# *Turn 5:
#   Q: Characterize your pain:
#   A:
# 	 * burning
# *Turn 6:
#   Q: How precisely is the pain located?
#   A:
# 	 * 7
# *Turn 7:
#   Q: How intense is the pain?
#   A:
# 	 * 4
# *Turn 8:
#   Q: How fast did the pain appear?
#   A:
# 	 * 0
# *Turn 9:
#   Q: Do you have swelling in one or more areas of your body?
#   A: N
# *Turn 10:
#   Q: Are you experiencing shortness of breath or difficulty breathing in a significant way?
#   A: Y
# *Turn 11:
#   Q: Do you have a cough?
#   A: Y
# *Turn 12:
#   Q: Do you have a chronic obstructive pulmonary disease (COPD)?
#   A: Y
# *Turn 13:
#   Q: Do you have a cough that produces colored or more abundant sputum than usual?
#   A: Y
# *Turn 14:
#   Q: Do you have a sore throat?
#   A: N
# *Turn 15:
#   Q: Do you have a fever (either felt or measured with a thermometer)?
#   A: N
# *Turn 16:
#   Q: Do you smoke cigarettes?
#   A: N
# *Turn 17:
#   Q: Have you noticed a wheezing sound when you exhale?
#   A: Y
# *Turn 18:
#   Q: Are your vaccinations up to date?
#   A: N
# *Turn 19:
#   Q: Do you have nasal congestion or a clear runny nose?
#   A: N
# Predicted differential:
# ----------------------
# Bronchitis, Pneumonia, Bronchiectasis, Acute COPD exacerbation / infection, Possible NSTEMI / STEMI, Panic attack, Pulmonary neoplasm, Unstable angina, Spontaneous pneumothorax, Pericarditis, Myocarditis, Stable angina, Guillain-Barré syndrome, Pulmonary embolism, Atrial fibrillation, Spontaneous rib fracture, Acute dystonic reactions, Anemia, Myasthenia gravis, Sarcoidosis, Tuberculosis, PSVT
# Ground-truth differential:
# -------------------------
# Acute COPD exacerbation / infection: 0.080, Bronchitis: 0.075, Pneumonia: 0.070, Bronchiectasis: 0.069, Pulmonary neoplasm: 0.061, Panic attack: 0.056, Possible NSTEMI / STEMI: 0.054, Unstable angina: 0.051, Pericarditis: 0.051, Spontaneous pneumothorax: 0.045, Myocarditis: 0.044, Stable angina: 0.042, Guillain-Barré syndrome: 0.040, Atrial fibrillation: 0.038, Spontaneous rib fracture: 0.034, Pulmonary embolism: 0.034, Acute dystonic reactions: 0.028, Myasthenia gravis: 0.028, Anemia: 0.028, Tuberculosis: 0.027, Sarcoidosis: 0.023, PSVT: 0.015, Chagas: 0.008
#
# ##########################################################
#
# Sex: M, Age: 49
# Initial evidence:
# 	 I feel palpitations
# Agent inquiries:
# ---------------
# *Turn 1:
#   Q: Do you have swelling in one or more areas of your body?
#   A: N
# *Turn 2:
#   Q: Do you have any lesions, redness or problems on your skin that you believe are related to the condition you are consulting for?
#   A: N
# *Turn 3:
#   Q: Do you have pain somewhere, related to your reason for consulting?
#   A: Y
# *Turn 4:
#   Q: Do you feel pain somewhere?
#   A:
# 	 * side of the chest(R)
# 	 * flank(R)
# 	 * iliac fossa(R)
# 	 * hypochondrium(L)
# 	 * breast(L)
# *Turn 5:
#   Q: Characterize your pain:
#   A:
# 	 * a cramp
# 	 * sharp
# *Turn 6:
#   Q: How precisely is the pain located?
#   A:
# 	 * 7
# *Turn 7:
#   Q: How intense is the pain?
#   A:
# 	 * 6
# *Turn 8:
#   Q: How fast did the pain appear?
#   A:
# 	 * 8
# *Turn 9:
#   Q: Are you experiencing shortness of breath or difficulty breathing in a significant way?
#   A: Y
# *Turn 10:
#   Q: Do you suffer from chronic anxiety?
#   A: N
# *Turn 11:
#   Q: Have you ever been diagnosed with depression?
#   A: Y
# *Turn 12:
#   Q: Have you ever had a head trauma?
#   A: Y
# *Turn 13:
#   Q: Do you feel like you are dying or were you afraid that you were about do die?
#   A: Y
# *Turn 14:
#   Q: Have you recently had numbness, loss of sensation or tingling, in both arms and legs and around your mouth?
#   A: Y
# *Turn 15:
#   Q: Do you suffer from fibromyalgia?
#   A: Y
# *Turn 16:
#   Q: Have you ever had a migraine or is a member of your family known to have migraines?
#   A: N
# *Turn 17:
#   Q: Have you had significantly increased sweating?
#   A: Y
# *Turn 18:
#   Q: Do you feel like you are detached from your own body or your surroundings?
#   A: Y
# *Turn 19:
#   Q: Do you have asthma or have you ever had to use a bronchodilator in the past?
#   A: Y
# *Turn 20:
#   Q: Do you feel anxious?
#   A: Y
# *Turn 21:
#   Q: Are you feeling nauseous or do you feel like vomiting?
#   A: N
# *Turn 22:
#   Q: Do you feel like you are (or were) choking or suffocating?
#   A: Y
# *Turn 23:
#   Q: Do any members of your immediate family have a psychiatric illness?
#   A: Y
# *Turn 24:
#   Q: Do you feel lightheaded and dizzy or do you feel like you are about to faint?
#   A: Y
# *Turn 25:
#   Q: Do you drink alcohol excessively or do you have an addiction to alcohol?
#   A: N
# *Turn 26:
#   Q: Do you currently, or did you ever, have numbness, loss of sensitivity or tingling anywhere on your body?
#   A: Y
# Predicted differential:
# ----------------------
# Panic attack, PSVT, Guillain-Barré syndrome, Possible NSTEMI / STEMI, Spontaneous pneumothorax, Pericarditis, Acute pulmonary edema, Unstable angina, Atrial fibrillation, Pulmonary embolism, Anaphylaxis, Anemia, Stable angina, GERD, Inguinal hernia, Scombroid food poisoning, Acute dystonic reactions, Myasthenia gravis, Pancreatic neoplasm, Sarcoidosis, SLE
# Ground-truth differential:
# -------------------------
# Panic attack: 0.090, PSVT: 0.074, Possible NSTEMI / STEMI: 0.068, Guillain-Barré syndrome: 0.067, Spontaneous pneumothorax: 0.061, Pericarditis: 0.057, Acute pulmonary edema: 0.057, Anemia: 0.053, Anaphylaxis: 0.053, Unstable angina: 0.051, Pulmonary embolism: 0.048, Atrial fibrillation: 0.048, Stable angina: 0.040, GERD: 0.039, Inguinal hernia: 0.036, Scombroid food poisoning: 0.034, Acute dystonic reactions: 0.029, Myasthenia gravis: 0.029, Sarcoidosis: 0.024, Pancreatic neoplasm: 0.022, SLE: 0.013, Chagas: 0.009
#
# ##########################################################
